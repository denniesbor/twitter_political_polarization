# %%
import os
import re
import json
import datetime
from datetime import date
from contextlib import contextmanager
import contractions

import snscrape.modules.twitter as sntwitter
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

# %%
nltk.download('stopwords')

# stopwords
stopwords_set = set(stopwords.words('english'))

# update stopwords set
stopwords_set.update(['s', 'will', 'amp',
                      'must', 'rt', 'american',
                      'americans', 're', '000'
                      ])
sid = SIA()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/denniesbor/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Data Collection
#
# Snscrape library is utilized to collect data from Twitter.
# A JSON file is loaded consisting of the two main categories in the study: geopolitical and social policies.
# Furthermore, in each category tree are the sub-groups and their associated keywords applied in text filtering.

# %%
# opening JSON file
with open('data.json') as json_file:
    categories = json.load(json_file)
categories
# Out:
# {'Social Policies': {'All': 'all',
#   'LGBTQ': ['transphobia',
#    'sexual identity',
#    'homophobia',
#    'trans',
#    'LGBTQ',
#    'biphobia',
#    'lgbtq'],
#   'internet': ['broadband', 'internet'],
#   'women health, and rights': ['abortion',
#    'maternal',
#    'momnibus',
#    'reproductive',
#    'birth',
#    'breast',
#    'pregnancy',
#    'pregnant'],
#   'substance and mental health': ['mental',
#    'suicide',
#    'restoringhope',
#    'marijuana',
#    'substance'],
#   'guns and assault weapons': ['guns',
#    'arms',
#    'shooter',
#    'assault',
#    'weapons',
#    'gun'],
#   'immigration': ['southern',
#    'immigration',
#    'migrant',
#    'border',
#    'immigrants'],
#   'energy': ['gallon',
#    'fossil',
#    'electric',
#    'gas',
#    'fuel',
#    'oil',
#    'pump',
#    'renewable',
#    'energy',
#    'petroleum'],
#   'climate change': ['greenhouse',
#    'fossil',
#    'climate',
#    'gas',
#    'emissions',
#    'carbon']},
#  'Geo Political Policies': {'All': 'all',
#   'china': ['china', 'ccp', 'communist', 'chinese'],
#   'chips science act': ['science act', 'chips act', 'chips'],
#   'taiwan': ['taiwan'],
#   'ukraine russia': ['vladimir',
#    'invasion',
#    'supplemental',
#    'putin',
#    'zelensky',
#    'appropriations',
#    'russia',
#    'ukraine',
#    'ukrainian',
#    'russian',
#    'invasion',
#    'nord stream',
#    'nordstream']}}

# %% [markdown]
# #### Get Twitter Handles of Legislators

# %%
# link us reps website
url = "https://pressgallery.house.gov/member-data/members-official-twitter-handles"


def get_house_reps():
    '''A function which scrapes US representatives and their Twitter handles

    ------------
    attributes

    return: list
    list of tuples of each house rep and the party
    ------------
    '''

    # read the housereps and pass into a dataframe
    print('***Fetching house reps ***')
    dfs = pd.read_html(url)
    print('***House reps response received***')
    house_reps = dfs[0]

    # make the first row as columns
    house_reps.columns = house_reps.iloc[1]

    df = house_reps.drop(index=0, inplace=False)[['Twitter Handle', 'Party']]
    df['Twitter Handle'] = df['Twitter Handle'].str.replace('@', '')

    # create list of tuples from the columns of dataframes
    house_rep_lists = list(zip(df['Twitter Handle'], df.Party))

    return house_rep_lists

# %%
get_house_reps()
# Out:
# ***Fetching house reps ***
# ***House reps response received***
# [('Twitter Handle', 'Party'),
#  ('RepAdams', 'D'),
#  ('Robert_Aderholt', 'R'),
#  ('RepPeteAguilar', 'D'),
#  ('RepRickAllen', 'R'),
#  ('RepColinAllred', 'D'),
#  ('MarkAmodeiNV2', 'R'),
#  ('RepArmstrongND', 'R'),
#  ('RepArrington', 'R'),
#  ('RepAuchincloss', 'D'),
#  ('RepCindyAxne', 'D'),
#  ('RepBrianBabin', 'R'),
#  ('RepDonBacon', 'R'),
#  ('RepJimBaird', 'R'),
#  ('RepBalderson', 'R'),
#  ('RepJimBanks', 'R'),
#  ('RepAndyBarr', 'R'),
#  ('RepBarragan', 'D'),
#  ('RepKarenBass', 'D'),
#  ('RepBeatty', 'D'),
#  ('RepBentz', 'R'),
#  ('RepBera', 'D'),
#  ('RepJackBergman', 'R'),
#  ('RepDonBeyer', 'D'),
#  ('RepBice', 'R'),
#  ('RepAndyBiggsAZ', 'R'),
#  ('RepGusBilirakis', 'R'),
#  ('RepDanBishop', 'R'),
#  ('SanfordBishop', 'D'),
#  ('repblumenauer', 'D'),
#  ('RepLBR', 'D'),
#  ('RepBoebert', 'R'),
#  ('RepBonamici', 'D'),
#  ('RepBost', 'R'),
#  ('RepBourdeaux', 'D'),
#  ('RepBowman', 'D'),
#  ('CongBoyle', 'D'),
#  ('RepKevinBrady', 'R'),
#  ('RepMoBrooks', 'R'),
#  ('RepAnthonyBrown', 'D'),
#  ('RepShontelBrown', 'D'),
#  ('RepBrownley', 'D'),
#  ('VernBuchanan', 'R'),
#  ('RepKenBuck', 'R'),
#  ('RepLarryBucshon', 'R'),
#  ('RepTedBudd', 'R'),
#  ('RepTimBurchett', 'R'),
#  ('michaelcburgess', 'R'),
#  ('RepCori', 'D'),
#  ('RepCheri', 'D'),
#  ('GKButterfield', 'D'),
#  ('KenCalvert', 'R'),
#  ('RepKatCammack', 'R'),
#  ('RepCarbajal', 'D'),
#  ('RepCardenas', 'D'),
#  ('RepMikeCarey', 'R'),
#  ('RepJerryCarl', 'R'),
#  ('RepAndreCarson', 'D'),
#  ('RepBuddyCarter', 'R'),
#  ('JudgeCarter', 'R'),
#  ('RepTroyCarter', 'D'),
#  ('RepCartwright', 'D'),
#  ('RepEdCase', 'D'),
#  ('RepCasten', 'D'),
#  ('USRepKCastor', 'D'),
#  ('JoaquinCastrotx', 'D'),
#  ('RepCawthorn', 'R'),
#  ('RepSteveChabot', 'R'),
#  ('RepLizCheney', 'R'),
#  ('CongresswomanSC', 'D'),
#  ('RepJudyChu', 'D'),
#  ('davidcicilline', 'D'),
#  ('RepCicilline', 'D'),
#  ('RepKClark', 'D'),
#  ('RepYvetteClarke', 'D'),
#  ('repcleaver', 'D'),
#  ('RepBenCline', 'R'),
#  ('RepCloudTX', 'R'),
#  ('WhipClyburn', 'D'),
#  ('Rep_Clyde', 'R'),
#  ('RepCohen', 'D'),
#  ('TomColeOK04', 'R'),
#  ('RepJamesComer', 'R'),
#  ('RepConnieConway', 'R'),
#  ('GerryConnolly', 'D'),
#  ('repjimcooper', 'D'),
#  ('RepLouCorrea', 'D'),
#  ('RepJimCosta', 'D'),
#  ('RepJoeCourtney', 'D'),
#  ('RepAngieCraig', 'D'),
#  ('RepRickCrawford', 'R'),
#  ('RepDanCrenshaw', 'R'),
#  ('RepCharlieCrist', 'D'),
#  ('RepJasonCrow', 'D'),
#  ('RepCuellar', 'D'),
#  ('RepJohnCurtis', 'R'),
#  ('RepDavids', 'D'),
#  ('WarrenDavidson', 'R'),
#  ('RepDannyDavis', 'D'),
#  ('RodneyDavis', 'R'),
#  ('RepDean', 'D'),
#  ('RepPeterDeFazio', 'D'),
#  ('RepDianaDeGette', 'D'),
#  ('rosadelauro', 'D'),
#  ('RepDelBene', 'D'),
#  ('RepValDemings', 'D'),
#  ('RepDeSaulnier', 'D'),
#  ('DesJarlaisTN04', 'R'),
#  ('RepTedDeutch', 'D'),
#  ('MarioDB', 'R'),
#  ('RepDebDingell', 'D'),
#  ('RepLloydDoggett', 'D'),
#  ('RepDonaldsPress', 'R'),
#  ('USRepMikeDoyle', 'D'),
#  ('RepJeffDuncan', 'R'),
#  ('DrNealDunnFL2', 'R'),
#  ('RepEllzey', 'R'),
#  ('RepTomEmmer', 'R'),
#  ('RepEscobar', 'D'),
#  ('RepAnnaEshoo', 'D'),
#  ('RepEspaillat', 'D'),
#  ('RepRonEstes', 'R'),
#  ('RepDwightEvans', 'D'),
#  ('RepPatFallon', 'R'),
#  ('RepFeenstra', 'R'),
#  ('RepDrewFerguson', 'R'),
#  ('repfinstad', 'R'),
#  ('RepFischbach', 'R'),
#  ('RepFitzgerald', 'R'),
#  ('RepBrianFitz', 'R'),
#  ('RepChuck', 'R'),
#  ('RepFletcher', 'D'),
#  ('USRepMikeFlood', nan),
#  ('repmayraflores', nan),
#  ('RepBillFoster', 'D'),
#  ('virginiafoxx', 'R'),
#  ('RepLoisFrankel', 'D'),
#  ('RepFranklin', 'R'),
#  ('RepRussFulcher', 'R'),
#  ('RepMattGaetz', 'R'),
#  ('RepGallagher', 'R'),
#  ('RepRubenGallego', 'D'),
#  ('RepGaramendi', 'D'),
#  ('RepGarbarino', 'R'),
#  ('RepMikeGarcia', 'R'),
#  ('RepSylviaGarcia', 'D'),
#  ('RepChuyGarcia', 'D'),
#  ('RepBobGibbs', 'R'),
#  ('RepCarlos', 'R'),
#  ('replouiegohmert', 'R'),
#  ('RepGolden', 'D'),
#  ('RepJimmyGomez', 'D'),
#  ('RepTonyGonzales', 'R'),
#  ('RepAGonzalez', 'R'),
#  ('RepGonzalez', 'D'),
#  ('RepJenniffer', 'R'),
#  ('RepBobGood', 'R'),
#  ('No official', 'R'),
#  ('RepGosar', 'R'),
#  ('RepJoshG', 'D'),
#  ('RepKayGranger', 'R'),
#  ('RepGarretGraves', 'R'),
#  ('RepSamGraves', 'R'),
#  ('RepAlGreen', 'D'),
#  ('RepMarkGreen', 'R'),
#  ('RepMTG', 'R'),
#  ('RepMGriffith', 'R'),
#  ('RepRaulGrijalva', 'D'),
#  ('RepGrothman', 'R'),
#  ('RepMichaelGuest', 'R'),
#  ('RepGuthrie', 'R'),
#  ('RepHagedorn', 'R'),
#  ('RepJoshHarder', 'D'),
#  ('RepAndyHarrisMD', 'R'),
#  ('RepHarshbarger', 'R'),
#  ('RepHartzler', 'R'),
#  ('RepJahanaHayes', 'D'),
#  ('repkevinhern', 'R'),
#  ('RepHerrell', 'R'),
#  ('HerreraBeutler', 'R'),
#  ('CongressmanHice', 'R'),
#  ('RepBrianHiggins', 'D'),
#  ('RepClayHiggins', 'R'),
#  ('RepFrenchHill', 'R'),
#  ('No official', 'D'),
#  ('RepAshleyHinson', 'R'),
#  ('RepTrey', 'R'),
#  ('RepHorsford', 'D'),
#  ('RepHoulahan', 'D'),
#  ('LeaderHoyer', 'D'),
#  ('RepRichHudson', 'R'),
#  ('RepHuffman', 'D'),
#  ('RepHuizenga', 'R'),
#  ('repdarrellissa', 'R'),
#  ('RepRonnyJackson', 'R'),
#  ('JacksonLeeTX18', 'D'),
#  ('RepJacobs', 'R'),
#  ('RepSaraJacobs', 'D'),
#  ('RepJayapal', 'D'),
#  ('RepJeffries', 'D'),
#  ('RepBillJohnson', 'R'),
#  ('RepDustyJohnson', 'R'),
#  ('RepEBJ', 'D'),
#  ('RepHankJohnson', 'D'),
#  ('RepMikeJohnson', 'R'),
#  ('RepMondaire', 'D'),
#  ('Jim_Jordan', 'R'),
#  ('RepDaveJoyce', 'R'),
#  ('RepJohnJoyce', 'R'),
#  ('RepKahele', 'D'),
#  ('RepMarcyKaptur', 'D'),
#  ('RepJohnKatko', 'R'),
#  ('USRepKeating', 'D'),
#  ('RepFredKeller', 'R'),
#  ('MikeKellyPA', 'R'),
#  ('RepRobinKelly', 'D'),
#  ('RepTrentKelly', 'R'),
#  ('RepRoKhanna', 'D'),
#  ('RepDanKildee', 'D'),
#  ('RepDerekKilmer', 'D'),
#  ('RepAndyKimNJ', 'D'),
#  ('RepYoungKim', 'R'),
#  ('RepRonKind', 'D'),
#  ('RepKinzinger', 'R'),
#  ('RepKirkpatrick', 'D'),
#  ('CongressmanRaja', 'D'),
#  ('RepAnnieKuster', 'D'),
#  ('RepDavidKustoff', 'R'),
#  ('RepLaHood', 'R'),
#  ('RepLaMalfa', 'R'),
#  ('RepConorLamb', 'D'),
#  ('RepDLamborn', 'R'),
#  ('JimLangevin', 'D'),
#  ('RepRickLarsen', 'D'),
#  ('RepJohnLarson', 'D'),
#  ('boblatta', 'R'),
#  ('RepLaTurner', 'R'),
#  ('RepLawrence', 'D'),
#  ('RepAlLawsonJr', 'D'),
#  ('RepBarbaraLee', 'D'),
#  ('RepSusieLee', 'D'),
#  ('RepTeresaLF', 'D'),
#  ('RepDLesko', 'R'),
#  ('repjulialetlow', 'R'),
#  ('RepAndyLevin', 'D'),
#  ('RepMikeLevin', 'D'),
#  ('RepTedLieu', 'D'),
#  ('RepZoeLofgren', 'D'),
#  ('USRepLong', 'R'),
#  ('RepLoudermilk', 'R'),
#  ('RepLowenthal', 'D'),
#  ('RepFrankLucas', 'R'),
#  ('RepBlaine', 'R'),
#  ('RepElaineLuria', 'D'),
#  ('RepStephenLynch', 'D'),
#  ('RepNancyMace', 'R'),
#  ('RepMalinowski', 'D'),
#  ('RepMalliotakis', 'R'),
#  ('RepMaloney', 'D'),
#  ('RepSeanMaloney', 'D'),
#  ('RepMann', 'R'),
#  ('RepKManning', 'D'),
#  ('RepThomasMassie', 'R'),
#  ('RepBrianMast', 'R'),
#  ('DorisMatsui', 'D'),
#  ('RepLucyMcBath', 'D'),
#  ('GOPLeader', 'R'),
#  ('RepMcCaul', 'R'),
#  ('RepLisaMcClain', 'R'),
#  ('RepMcClintock', 'R'),
#  ('BettyMcCollum04', 'D'),
#  ('RepMcEachin', 'D'),
#  ('RepMcGovern', 'D'),
#  ('PatrickMcHenry', 'R'),
#  ('RepMcKinley', 'R'),
#  ('RepMcNerney', 'D'),
#  ('RepGregoryMeeks', 'D'),
#  ('RepMeijer', 'R'),
#  ('RepGraceMeng', 'D'),
#  ('RepMeuser', 'R'),
#  ('RepKweisiMfume', 'D'),
#  ('RepCarolMiller', 'R'),
#  ('RepMaryMiller', 'R'),
#  ('RepMMM', 'R'),
#  ('RepMoolenaar', 'R'),
#  ('RepAlexMooney', 'R'),
#  ('RepBarryMoore', 'R'),
#  ('RepBlakeMoore', 'R'),
#  ('RepGwenMoore', 'D'),
#  ('RepJoeMorelle', 'D'),
#  ('teammoulton', 'D'),
#  ('RepMrvan', 'D'),
#  ('RepMullin', 'R'),
#  ('RepGregMurphy', 'R'),
#  ('RepStephMurphy', 'D'),
#  ('RepJerryNadler', 'D'),
#  ('gracenapolitano', 'D'),
#  ('RepRichardNeal', 'D'),
#  ('RepJoeNeguse', 'D'),
#  ('RepTroyNehls', 'R'),
#  ('RepNewhouse', 'R'),
#  ('RepMarieNewman', 'D'),
#  ('DonaldNorcross', 'D'),
#  ('RepRalphNorman', 'R'),
#  ('EleanorNorton', 'D'),
#  ('RepDevinNunes', 'R'),
#  ('JayObernolte', 'R'),
#  ('RepAOC', 'D'),
#  ('RepOHalleran', 'D'),
#  ('Ilhan', 'D'),
#  ('RepBurgessOwens', 'R'),
#  ('CongPalazzo', 'R'),
#  ('FrankPallone', 'D'),
#  ('USRepGaryPalmer', 'R'),
#  ('RepJimmyPanetta', 'D'),
#  ('RepChrisPappas', 'D'),
#  ('BillPascrell', 'D'),
#  ('RepDonaldPayne', 'D'),
#  ('SpeakerPelosi', 'D'),
#  ('TBD', 'D'),
#  ('RepGregPence', 'R'),
#  ('RepPerlmutter', 'D'),
#  ('RepScottPerry', 'R'),
#  ('RepScottPeters', 'D'),
#  ('RepPfluger', 'R'),
#  ('RepDeanPhillips', 'D'),
#  ('chelliepingree', 'D'),
#  ('StaceyPlaskett', 'D'),
#  ('repmarkpocan', 'D'),
#  ('RepKatiePorter', 'D'),
#  ('congbillposey', 'R'),
#  ('RepPressley', 'D'),
#  ('RepDavidEPrice', 'D'),
#  ('RepMikeQuigley', 'D'),
#  ('RepAmata', 'R'),
#  ('RepRaskin', 'D'),
#  ('GReschenthaler', 'R'),
#  ('RepKathleenRice', 'D'),
#  ('RepTomRice', 'R'),
#  ('cathymcmorris', 'R'),
#  ('RepHalRogers', 'R'),
#  ('RepMikeRogersAL', 'R'),
#  ('RepJohnRose', 'R'),
#  ('RepRosendale', 'R'),
#  ('RepDeborahRoss', 'D'),
#  ('RepDavidRouzer', 'R'),
#  ('RepChipRoy', 'R'),
#  ('RepRoybalAllard', 'D'),
#  ('RepRaulRuizMD', 'D'),
#  ('Call_Me_Dutch', 'D'),
#  ('RepBobbyRush', 'D'),
#  ('RepRutherfordFL', 'R'),
#  ('RepPatRyanNY', 'D'),
#  ('RepTimRyan', 'D'),
#  ('Kilili_Sablan', 'D'),
#  ('RepMariaSalazar', 'R'),
#  ('GuamCongressman', 'D'),
#  ('RepLindaSanchez', 'D'),
#  ('RepSarbanes', 'D'),
#  ('SteveScalise', 'R'),
#  ('RepMGS', 'D'),
#  ('RepSchakowsky', 'D'),
#  ('RepAdamSchiff', 'D'),
#  ('RepSchneider', 'D'),
#  ('RepSchrader', 'D'),
#  ('RepKimSchrier', 'D'),
#  ('RepDavid', 'R'),
#  ('AustinScottGA08', 'R'),
#  ('repdavidscott', 'D'),
#  ('BobbyScott', 'D'),
#  ('RepSempolinski', 'R'),
#  ('PeteSessions', 'R'),
#  ('RepTerriSewell', 'D'),
#  ('BradSherman', 'D'),
#  ('RepSherrill', 'D'),
#  ('CongMikeSimpson', 'R'),
#  ('RepSires', 'D'),
#  ('RepSlotkin', 'D'),
#  ('RepAdamSmith', 'D'),
#  ('RepAdrianSmith', 'R'),
#  ('No official', 'R'),
#  ('RepJasonSmith', 'R'),
#  ('RepSmucker', 'R'),
#  ('RepDarrenSoto', 'D'),
#  ('RepSpanberger', 'D'),
#  ('RepSpartz', 'R'),
#  ('RepSpeier', 'D'),
#  ('Rep_Stansbury', nan),
#  ('RepGregStanton', 'D'),
#  ('RepPeteStauber', 'R'),
#  ('RepSteel', 'R'),
#  ('RepStefanik', 'R'),
#  ('RepBryanSteil', 'R'),
#  ('RepGregSteube', 'R'),
#  ('RepHaleyStevens', 'D'),
#  ('RepChrisStewart', 'R'),
#  ('RepStricklandWA', 'D'),
#  ('RepTomSuozzi', 'D'),
#  ('RepSwalwell', 'D'),
#  ('RepMarkTakano', 'D'),
#  ('RepVanTaylor', 'R'),
#  ('RepTenney', 'R'),
#  ('BennieGThompson', 'D'),
#  ('CongressmanGT', 'R'),
#  ('RepThompson', 'D'),
#  ('RepTiffany', 'R'),
#  ('RepTimmons', 'R'),
#  ('repdinatitus', 'D'),
#  ('RepRashida', 'D'),
#  ('RepPaulTonko', 'D'),
#  ('NormaJTorres', 'D'),
#  ('RepRitchie', 'D'),
#  ('RepLoriTrahan', 'D'),
#  ('RepDavidTrone', 'D'),
#  ('RepMikeTurner', 'R'),
#  ('RepUnderwood', 'D'),
#  ('RepFredUpton', 'R'),
#  ('RepDavidValadao', 'R'),
#  ('No official', 'R'),
#  ('RepBethVanDuyne', 'R'),
#  ('RepJuanVargas', 'D'),
#  ('RepVeasey', 'D'),
#  ('NydiaVelazquez', 'D'),
#  ('RepAnnWagner', 'R'),
#  ('RepWalberg', 'R'),
#  ('RepWalorski', 'R'),
#  ('RepWaltzPress', 'R'),
#  ('RepDWStweets', 'D'),
#  ('RepMaxineWaters', 'D'),
#  ('RepBonnie', 'D'),
#  ('TXRandy14', 'R'),
#  ('RepWebster', 'R'),
#  ('PeterWelch', 'D'),
#  ('RepBradWenstrup', 'R'),
#  ('RepWesterman', 'R'),
#  ('RepWexton', 'D'),
#  ('RepSusanWild', 'D'),
#  ('RepNikema', 'D'),
#  ('RepRWilliams', 'R'),
#  ('RepWilson', 'D'),
#  ('RepJoeWilson', 'R'),
#  ('RobWittman', 'R'),
#  ('rep_stevewomack', 'R'),
#  ('RepJohnYarmuth', 'D'),
#  ('RepLeeZeldin', 'R')]

# %%
def get_time_delta(update: int) -> int:
    ''' Get the time delta of the tweets to be scraped. Initializing the database
    is set to the first Jan of 2021. A user can specify the time delta to fetch the tweets since today

    input update: int

    returns -> int
        time delta in unix
    '''
    
    # date time
    date_from = datetime.datetime(2021, 1, 1)
    date_now = datetime.datetime.now()
    delta = (date_now - date_from).days

    if(update):
        delta = update

    time_delta1 = datetime.timedelta(days=delta)
    date_since = date_now-time_delta1

    # extract unix time
    unix = datetime.datetime.timestamp(date_since)
    
    return unix

# %%
def contractors(text):
    '''Cleaning the texts, non-alphanumeric letters are removed
    including those in shortened words such as can't, won't, etc.
    This function expands these words.
    '''

    # creating an empty list
    expanded_words = []
    
    for word in text.split():
        # using contractions.fix to expand the shortened words
        expanded_words.append(contractions.fix(word))

    expanded_text = ' '.join(expanded_words)
    return expanded_text


def clean_tweets(tweet:str):
    """ This function cleans the tweets
    Attrs
    ---------
    input: str
    tweet
    Returns
    ---------
    output: str
    clean tweet 
    """

    tweet = contractors(tweet)
    tweet = tweet.lower()
    tweet = re.sub('@[^\s]+', '', tweet)  # remove twitter handlers
    # tweet = re.sub(r'\B#\S+','',tweet)  # remove hashtags
    tweet = re.sub(r"http\S+", "", tweet)  # Remove URLS
    tweet = re.sub(r'\s+', ' ', tweet, flags=re.I)  # substitute multiple spaces with single space
    tweet = ' '.join(re.findall(r'\w+', tweet))  # remove all the special characters
    tweet = re.sub(r'(^| ).(( ).)*( |$)', ' ', tweet)  #remove all single characters

    return tweet

# %%
def get_policy_cat(text):
    '''This function searches through a tweet text and categorizes it into
    their respective categories, e.g., geo-political or social, and further
    break down into sub-categories, e.g., climate change, etc.
    '''

    social_policy = ''
    geopolitical_policy = ''
    policies = ''
    policy_cat = ''

    for policy_type in categories:

        for policy in categories[policy_type]:
            if policy != 'All':
                search = '|'.join([f"{p} " for p in categories[policy_type][policy]])
                regexp = re.search(r'%s' % search, text, re.I)

                if regexp:
                    policies += policy+'|'

                    if policy_type in policy_cat:
                        pass
                    else:
                        policy_cat += policy_type+' '
                        if(policy_type == 'Social Policies'):
                            social_policy += policy_type
                        if(policy_type == 'Geo Political Policies'):
                            geopolitical_policy += policy_type
            else:
                pass

    return pd.Series([social_policy, geopolitical_policy, policies.split('|')])

# %%
def compute_sentiments(df):
    """Function which computes the sentiments of a dataframe texts. 
    """
    
    df['sentiments'] = df['clean_text'].apply(lambda x: sid.polarity_scores(' '.join(re.findall(r'\w+', x.lower()))))

    # extract scores of sentiments. 0.00001 added incase of a score of 0
    df['positive_sentiment'] = df['sentiments'].apply(lambda x: x['pos']+1*(10**-6))
    df['neutral_sentiment'] = df['sentiments'].apply(lambda x: x['neu']+1*(10**-6))
    df['negative_sentiment'] = df['sentiments'].apply(lambda x: x['neg']+1*(10**-6))
    df['compound_sentiment'] = df['sentiments'].apply(lambda x: x['compound']+1*(10**-6))
    df['sentiment_text'] = df['compound_sentiment'].apply(lambda x: 'positive' if x > 0.05 else ('negative' if x < -0.05 else 'neutral'))
    df.drop(columns=['sentiments'], inplace=True)

    print('Finished computing sentiment analysis \n')

    return df

# %%
def fetch_tweets(username, party, update=False):
    ''' A function that fetch tweets from a user and return as pandas DF
    '''

    unix = get_time_delta(update)

    tweet_list = []
    compile = re.compile(r'^RT ')

    print(f"Fetching tweets of {username}")
    # get tweets
    for tweet_obj in sntwitter.TwitterSearchScraper(f'from:{username}').get_items():

        created_at = tweet_obj.date  # utc time tweet created
        tweet = tweet_obj.rawContent  # tweet
        unix_created = datetime.datetime.timestamp(created_at)

        if (not re.search(compile, tweet)) and (unix_created >= unix):
            tweet_list.append(
                dict(
                    tweet_id=tweet_obj.id,
                    username=tweet_obj.user.username,
                    party=party,
                    tweet=tweet,
                    favorite_count=tweet_obj.likeCount,
                    retweet_count=tweet_obj.retweetCount,
                    created_at=created_at,
                    source=tweet_obj.sourceLabel
                    ))
        else:
            break

    if tweet_list == []:
        print('Empty Tweets')
        return
    else:

        # create dataframe
        df = pd.DataFrame(tweet_list)
        df['clean_text'] = df['tweet'].apply(clean_tweets)
        print('finished cleaning tweets')

        df[['social_policy', 'geopolitical_policy', 'policies']] = df.clean_text.apply(get_policy_cat)

        # drop empty policies
        df = df[df['policies'].map(lambda text: len(text)) > 1]

        df = compute_sentiments(df)
        return df

# %%
def tweets(update_time: int) -> pd.DataFrame:
    
    '''export tweets into a pandas dataframe for analysis
    '''
    
    dfs = []
    house_reps = get_house_reps()
    for user, party in house_reps[0:]:

        df = fetch_tweets(user, party, update=update_time)

        try:
            if df:
                pass
        except ValueError:
          dfs.append(df)
    if len(dfs)>1:
        df = pd.concat(dfs)
        df.reset_index(inplace=True, drop=True)
        return df

# %%
# fetch tweets from the past 90 days

df = tweets(90)

df.to_csv('tweets.csv', index=False)

df = pd.read_csv('tweets.csv')

# evaluate string into list
df.policies.apply(eval)
# Out:
# ***Fetching house reps ***
# ***House reps response received***
# Fetching tweets of Twitter Handle
# Empty Tweets
# Fetching tweets of RepAdams
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Robert_Aderholt
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPeteAguilar
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRickAllen
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepColinAllred
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of MarkAmodeiNV2
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepArmstrongND
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepArrington
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAuchincloss
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCindyAxne
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBrianBabin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDonBacon
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJimBaird
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBalderson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJimBanks
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAndyBarr
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBarragan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKarenBass
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBeatty
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBentz
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBera
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJackBergman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDonBeyer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBice
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAndyBiggsAZ
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGusBilirakis
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDanBishop
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of SanfordBishop
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repblumenauer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLBR
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBoebert
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBonamici
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBost
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBourdeaux
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBowman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongBoyle
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKevinBrady
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMoBrooks
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAnthonyBrown
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepShontelBrown
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBrownley
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of VernBuchanan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKenBuck
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLarryBucshon
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTedBudd
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTimBurchett
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of michaelcburgess
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCori
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCheri
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of GKButterfield
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of KenCalvert
# Empty Tweets
# Fetching tweets of RepKatCammack
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCarbajal
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCardenas
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeCarey
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJerryCarl
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAndreCarson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBuddyCarter
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of JudgeCarter
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTroyCarter
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCartwright
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepEdCase
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCasten
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of USRepKCastor
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of JoaquinCastrotx
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCawthorn
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSteveChabot
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLizCheney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongresswomanSC
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJudyChu
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of davidcicilline
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCicilline
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKClark
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepYvetteClarke
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repcleaver
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBenCline
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCloudTX
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of WhipClyburn
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Rep_Clyde
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCohen
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of TomColeOK04
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJamesComer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepConnieConway
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of GerryConnolly
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repjimcooper
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLouCorrea
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJimCosta
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJoeCourtney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAngieCraig
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRickCrawford
# Empty Tweets
# Fetching tweets of RepDanCrenshaw
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCharlieCrist
# Empty Tweets
# Fetching tweets of RepJasonCrow
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCuellar
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJohnCurtis
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavids
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of WarrenDavidson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDannyDavis
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RodneyDavis
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDean
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPeterDeFazio
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDianaDeGette
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of rosadelauro
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDelBene
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepValDemings
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDeSaulnier
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of DesJarlaisTN04
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTedDeutch
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of MarioDB
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDebDingell
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLloydDoggett
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDonaldsPress
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of USRepMikeDoyle
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJeffDuncan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of DrNealDunnFL2
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepEllzey
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTomEmmer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepEscobar
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAnnaEshoo
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepEspaillat
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRonEstes
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDwightEvans
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPatFallon
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFeenstra
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDrewFerguson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repfinstad
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFischbach
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFitzgerald
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBrianFitz
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepChuck
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFletcher
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of USRepMikeFlood
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repmayraflores
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBillFoster
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of virginiafoxx
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLoisFrankel
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFranklin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRussFulcher
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMattGaetz
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGallagher
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRubenGallego
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGaramendi
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGarbarino
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeGarcia
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSylviaGarcia
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepChuyGarcia
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBobGibbs
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCarlos
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of replouiegohmert
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGolden
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJimmyGomez
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTonyGonzales
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAGonzalez
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGonzalez
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJenniffer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBobGood
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of No official
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGosar
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJoshG
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKayGranger
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGarretGraves
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSamGraves
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAlGreen
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMarkGreen
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMTG
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMGriffith
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRaulGrijalva
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGrothman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMichaelGuest
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGuthrie
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHagedorn
# Empty Tweets
# Fetching tweets of RepJoshHarder
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAndyHarrisMD
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHarshbarger
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHartzler
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJahanaHayes
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repkevinhern
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHerrell
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of HerreraBeutler
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongressmanHice
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBrianHiggins
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepClayHiggins
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFrenchHill
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of No official
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAshleyHinson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTrey
# Empty Tweets
# Fetching tweets of RepHorsford
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHoulahan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of LeaderHoyer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRichHudson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHuffman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHuizenga
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repdarrellissa
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRonnyJackson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of JacksonLeeTX18
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJacobs
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSaraJacobs
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJayapal
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJeffries
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBillJohnson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDustyJohnson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepEBJ
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHankJohnson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeJohnson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMondaire
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Jim_Jordan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDaveJoyce
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJohnJoyce
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKahele
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMarcyKaptur
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJohnKatko
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of USRepKeating
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFredKeller
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of MikeKellyPA
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRobinKelly
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTrentKelly
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRoKhanna
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDanKildee
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDerekKilmer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAndyKimNJ
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepYoungKim
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRonKind
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKinzinger
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKirkpatrick
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongressmanRaja
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAnnieKuster
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavidKustoff
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLaHood
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLaMalfa
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepConorLamb
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDLamborn
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of JimLangevin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRickLarsen
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJohnLarson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of boblatta
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLaTurner
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLawrence
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAlLawsonJr
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBarbaraLee
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSusieLee
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTeresaLF
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDLesko
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repjulialetlow
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAndyLevin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeLevin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTedLieu
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepZoeLofgren
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of USRepLong
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLoudermilk
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLowenthal
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFrankLucas
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBlaine
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepElaineLuria
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepStephenLynch
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepNancyMace
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMalinowski
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMalliotakis
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMaloney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSeanMaloney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMann
# Empty Tweets
# Fetching tweets of RepKManning
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepThomasMassie
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBrianMast
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of DorisMatsui
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLucyMcBath
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of GOPLeader
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMcCaul
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLisaMcClain
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMcClintock
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of BettyMcCollum04
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMcEachin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMcGovern
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of PatrickMcHenry
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMcKinley
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMcNerney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGregoryMeeks
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMeijer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGraceMeng
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMeuser
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKweisiMfume
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepCarolMiller
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMaryMiller
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMMM
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMoolenaar
# Empty Tweets
# Fetching tweets of RepAlexMooney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBarryMoore
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBlakeMoore
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGwenMoore
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJoeMorelle
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of teammoulton
# Empty Tweets
# Fetching tweets of RepMrvan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMullin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGregMurphy
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepStephMurphy
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJerryNadler
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of gracenapolitano
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRichardNeal
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJoeNeguse
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTroyNehls
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepNewhouse
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMarieNewman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of DonaldNorcross
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRalphNorman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of EleanorNorton
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDevinNunes
# Empty Tweets
# Fetching tweets of JayObernolte
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAOC
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepOHalleran
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Ilhan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBurgessOwens
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongPalazzo
# Empty Tweets
# Fetching tweets of FrankPallone
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of USRepGaryPalmer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJimmyPanetta
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepChrisPappas
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of BillPascrell
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDonaldPayne
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of SpeakerPelosi
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of TBD
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGregPence
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPerlmutter
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepScottPerry
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepScottPeters
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPfluger
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDeanPhillips
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of chelliepingree
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of StaceyPlaskett
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repmarkpocan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKatiePorter
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of congbillposey
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPressley
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavidEPrice
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeQuigley
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAmata
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRaskin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of GReschenthaler
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKathleenRice
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTomRice
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of cathymcmorris
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHalRogers
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeRogersAL
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJohnRose
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRosendale
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDeborahRoss
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavidRouzer
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepChipRoy
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRoybalAllard
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRaulRuizMD
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Call_Me_Dutch
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBobbyRush
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRutherfordFL
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPatRyanNY
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTimRyan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Kilili_Sablan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMariaSalazar
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of GuamCongressman
# Empty Tweets
# Fetching tweets of RepLindaSanchez
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSarbanes
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of SteveScalise
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMGS
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSchakowsky
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAdamSchiff
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSchneider
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSchrader
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepKimSchrier
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavid
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of AustinScottGA08
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repdavidscott
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of BobbyScott
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSempolinski
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of PeteSessions
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTerriSewell
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of BradSherman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSherrill
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongMikeSimpson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSires
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSlotkin
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAdamSmith
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAdrianSmith
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of No official
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJasonSmith
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSmucker
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDarrenSoto
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSpanberger
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSpartz
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSpeier
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of Rep_Stansbury
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGregStanton
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPeteStauber
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSteel
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepStefanik
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBryanSteil
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepGregSteube
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepHaleyStevens
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepChrisStewart
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepStricklandWA
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTomSuozzi
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSwalwell
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMarkTakano
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepVanTaylor
# Empty Tweets
# Fetching tweets of RepTenney
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of BennieGThompson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of CongressmanGT
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepThompson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTiffany
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepTimmons
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of repdinatitus
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRashida
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepPaulTonko
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of NormaJTorres
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRitchie
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLoriTrahan
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavidTrone
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMikeTurner
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepUnderwood
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepFredUpton
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDavidValadao
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of No official
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBethVanDuyne
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJuanVargas
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepVeasey
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of NydiaVelazquez
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepAnnWagner
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepWalberg
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepWalorski
# Empty Tweets
# Fetching tweets of RepWaltzPress
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepDWStweets
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepMaxineWaters
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBonnie
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of TXRandy14
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepWebster
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of PeterWelch
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepBradWenstrup
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepWesterman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepWexton
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepSusanWild
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepNikema
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepRWilliams
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepWilson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJoeWilson
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RobWittman
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of rep_stevewomack
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepJohnYarmuth
# finished cleaning tweets
# Finished computing sentiment analysis
#
# Fetching tweets of RepLeeZeldin
# finished cleaning tweets
# Finished computing sentiment analysis
# 0                              [LGBTQ, ]
# 1             [energy, climate change, ]
# 2           [women health, and rights, ]
# 3           [guns and assault weapons, ]
# 4           [women health, and rights, ]
#                       ...
# 13509                    [immigration, ]
# 13510                    [immigration, ]
# 13511                    [immigration, ]
# 13512    [substance and mental health, ]
# 13513                    [immigration, ]
# Name: policies, Length: 13514, dtype: object

# %%
df.shape
# Out:
# (13514, 17)

# %%
df.head(5)
# Out:
#               tweet_id  username party  \
# 0  1594716768500686849  RepAdams     D
# 1  1587829863980883968  RepAdams     D
# 2  1583131771671318528  RepAdams     D
# 3  1577015599234183168  RepAdams     D
# 4  1575523426848342016  RepAdams     D
#
#                                                tweet  favorite_count  \
# 0  My statement on the tragic events in Colorado ...               9
# 1  I am fighting Big Oil by taking on unlawful pr...              13
# 2  "Oversight Committee and Black Maternal Health...              21
# 3  Some companies introduced "shoot now, pay late...              14
# 4  Members of the @HouseGOP are doubling down on ...              11
#
#    retweet_count                 created_at           source  \
# 0              5  2022-11-21 15:38:00+00:00  Twitter Web App
# 1              7  2022-11-02 15:31:54+00:00  Twitter Web App
# 2             16  2022-10-20 16:23:22+00:00  Twitter Web App
# 3              6  2022-10-03 19:19:53+00:00  Twitter Web App
# 4              8  2022-09-29 16:30:31+00:00        TweetDeck
#
#                                           clean_text    social_policy  \
# 0  my statement on the tragic events in colorado ...  Social Policies
# 1   am fighting big oil by taking on unlawful pri...  Social Policies
# 2  oversight committee and black maternal health ...  Social Policies
# 3  some companies introduced shoot now pay later ...  Social Policies
# 4  members of the are doubling down on the extrem...  Social Policies
#
#   geopolitical_policy                          policies  positive_sentiment  \
# 0                 NaN                     ['LGBTQ', '']            0.039001
# 1                 NaN  ['energy', 'climate change', '']            0.000001
# 2                 NaN  ['women health, and rights', '']            0.045001
# 3                 NaN  ['guns and assault weapons', '']            0.119001
# 4                 NaN  ['women health, and rights', '']            0.157001
#
#    neutral_sentiment  negative_sentiment  compound_sentiment sentiment_text
# 0           0.563001            0.399001           -0.972899       negative
# 1           0.885001            0.115001           -0.490199       negative
# 2           0.955001            0.000001            0.177901       positive
# 3           0.796001            0.084001            0.381801       positive
# 4           0.700001            0.143001            0.128001       positive

# %%
df.loc[4, 'tweet']
# Out:
# "Members of the @HouseGOP are doubling down on the extreme MAGA agenda:\n\n🚨 Criminalizing reproductive care\n🚨 Raising seniors' drug prices and slashing Social Security &amp; Medicare\n🚨 Attacking our Democracy &amp; Government"

# %% [markdown]
# ### To Do List -  BoxPlot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [204], line 1
# ----> 1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [202], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
