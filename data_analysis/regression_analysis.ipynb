# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import re
import json
import time
import requests
from datetime import datetime, date

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from bs4 import BeautifulSoup
import tabula
import pandas as pd

# %% [markdown]
# ## The Govtrack ideology scores downloaded from Govtrack.us
# The 2020 report dates from Jan 3 -2019 to Jan 3 - 2021 whereas the 2022 report is dated Jan 3 - 2021 to Jan 3 - 2022. The Govtrack
# report of the current legislators is yet to be released.

# %%
# read the 2020 reports and merge
df_2020_rep = pd.read_csv("raw_data/govtrack-stats-2020-house-ideology.csv")
df_2020_sen = pd.read_csv("raw_data/govtrack-stats-2020-senate-ideology.csv")

df_2020 = pd.concat([df_2020_rep, df_2020_sen])
df_2020.district = df_2020.district.fillna("Senator")
df_2020["period"] = 2020
df_2020.district = df_2020.district.apply(lambda dis: dis if type(dis) == str else dis)

# read the 2022 reports
df_2022_rep = pd.read_csv("raw_data/govtrack-stats-2022-house-ideology.csv")
df_2022_sen = pd.read_csv("raw_data/govtrack-stats-2022-senate-ideology.csv")

df_2022 = pd.concat([df_2022_rep, df_2022_sen])
df_2022["period"] = 2022
df_2022.district = df_2022.district.fillna("Senator")
df_2022.district = df_2022.district.apply(lambda dis: dis if type(dis) == str else dis)

# %% [markdown]
# ### Religious denominations in Congress

# %%
# read religion composition tables

dfs_religion_2020 = tabula.read_pdf(
    "raw_data/Faith-on-the-Hill-116-detailed-tables.pdf", pages="all"
)
dfs_religion_2022 = tabula.read_pdf(
    "raw_data/01.04.21_faith_on_the_hill_detailed.table_.update.pdf", pages="all"
)

# %%
def concat_pdf(dfs_, year):
    "Concatenate religious denominations"
    dfs = []
    for i, df in enumerate(dfs_):
        if i == 0 and year == 2020:
            pass
        else:
            df = pd.concat([df, df.columns.to_frame().T], ignore_index=True)

            if year == 2022:
                df.columns = [
                    "State",
                    "District",
                    "Name",
                    "Party",
                    "Freshman",
                    "Denominational family",
                ]
            else:
                df.columns = dfs_religion_2020[0].columns

        df.District = df.District.apply(
            lambda x: "Senator"
            if x == "Sen" or x == "Senator"
            else "0"
            if x == "At-Large" or x == "At-large"
            else x
        )

        dfs.append(df)

    return pd.concat(dfs)

# %%
df_religion_2020 = concat_pdf(dfs_religion_2020, 2020)
df_religion_2022 = concat_pdf(dfs_religion_2022, 2022)

# concatenate last and full name
df_religion_2020["Full_Name"] = df_religion_2020.apply(
    lambda row: row["First/middle"] + " " + row["Last"], axis=1
)

# %% [markdown]
# ## Veterans in Congress - Data from (militarytimes.com)

# %%
def get_veterans(url):
    # using selenium to acquire veterans in the congress. Data source infogram

    # Create a new Chrome session
    driver = webdriver.Chrome()
    wait = WebDriverWait(driver, 20)

    # Load the web page
    driver.get(url)  # Wait for the page to fully load
    driver.maximize_window()

    wait.until(
        EC.visibility_of_element_located((By.CSS_SELECTOR, ".igc-table-container"))
    )
    # short pause added in order to make sure all the elements are loaded after we know the first element was loaded
    time.sleep(0.5)

    soup = BeautifulSoup(driver.page_source, "lxml")

    div = soup.select_one("div.igc-table-container")

    df = pd.read_html(str(div))[0]

    df["State"] = df.District.apply(
        lambda dis: dis.split(" ")[0] if dis != "Georgia" else "GA"
    )
    df["District"] = df.District.apply(
        lambda dis: "0"
        if len(dis.split(" ")) == 1 or dis.split(" ")[1] == "(House)"
        else str(dis.split(" ")[1])
    )
    df["District"] = df.District.apply(
        lambda dis: "Senator" if dis == "Sen" or dis == "Senate" else dis
    )
    df["Party"] = df.Party.apply(
        lambda party: "R"
        if party == "GOP" or party == "Republican"
        else "D"
        if party == "Dem"
        else party
    )

    return df

# %%
df_mil_2020 = get_veterans(
    "https://e.infogram.com/b28274cb-26b9-441f-9994-a8eb8558839b?src=embed"
)
df_mil_2020.to_csv("raw_data/veterans_in_congress_116.csv", index=False)

df_mil_2022 = get_veterans(
    "https://infogram.com/veterans-in-117th-congress-1hxj48ppv9zz52v"
)
df_mil_2022.to_csv("raw_data/veterans_in_congress_117.csv", index=False)

# %%
# Merge the Congressmen religion and "is veteran" dataframes

df_mil_2020
# Out:
#    District Party              Name In office now?  Gender            Service  \
# 0         9     R      Doug Collins            Yes    Male         AF Reserve
# 1   Senator     R         Mike Enzi            Yes    Male          Air Force
# 2   Senator     R    Lindsey Graham            Yes    Male          Air Force
# 3         6     D  Chrissy Houlahan             No  Female          Air Force
# 4         5     R  Denver Riggleman             No    Male          Air Force
# ..      ...   ...               ...            ...     ...                ...
# 91        1     R       Andy Harris            Yes    Male       Navy Reserve
# 92       20     D     Jimmy Panetta            Yes    Male       Navy Reserve
# 93        3     R         Jim Banks            Yes    Male       Navy Reserve
# 94        4     R    Steven Palazzo            Yes    Male  Marine Corps/Army
# 95  Senator     R    Martha McSally             No  Female          Air Force
#
#             Era       Combat tours State
# 0   2000s-2010s                OIF    GA
# 1   1960s-1970s               none    WY
# 2   1980s-2010s                OIF    SC
# 3         1980s               none    PA
# 4         1990s               none    VA
# ..          ...                ...   ...
# 91  1980s-2010s       Desert Storm    MD
# 92        2000s                OEF    CA
# 93        2010s                OEF    IN
# 94  1980s-2010s  Desert Storm, OIF    MS
# 95  1990s-2010s           OIF, OEF    AZ
#
# [96 rows x 9 columns]

# %%
# match the names and merge the dataframes using Levenshtein logic

import fuzzy_pandas as fpd

# %%
# rename religion dataframe

df_religion_2020.rename(
    columns={"Full_Name": "Name_Rel", "Last": "Last_Name"}, inplace=True
)
df_mil_2020.rename(columns={"Name": "Name_Mil"}, inplace=True)

matches = fpd.fuzzy_merge(
    df_religion_2020,
    df_mil_2020,
    left_on=["Name_Rel", "State", "District", "Party"],
    right_on=["Name_Mil", "State", "District", "Party"],
    method="levenshtein",
    threshold=0.55,
    ignore_case=True,
    ignore_nonalpha=True,
    ignore_nonlatin=True,
    ignore_order_words=True,
)
matches["Military"] = "Yes"

# left join df_religion with matches

df_religion_2020 = df_religion_2020.merge(
    matches[["Name_Rel", "Name_Mil", "Last_Name", "Military"]], how="left"
)
df_religion_2020.Military = df_religion_2020.Military.fillna("No")
df_religion_2020.Last_Name = df_religion_2020.Last_Name.apply(
    lambda name: name.split(" ")[0]
)

# %% [markdown]
# ## Other Congress biographies and social links - source https://github.com/unitedstates/congress-legislators

# %%
congress_historical = pd.read_csv("raw_data/legislators-historical.csv")
congress_current = pd.read_csv("raw_data/legislators-current.csv")
congress_data = pd.concat([congress_historical, congress_current])
congress_data.reset_index(inplace=True, drop=True)

# congress 2020
congress_2020_senate = pd.read_csv(
    "raw_data/116th Congress Members Guide with Elections and Demographic Data by District - Senate.csv"
)
congress_2020_senate["Period"] = 116

congress_2020_house = pd.read_csv(
    "raw_data/116th Congress Members Guide with Elections and Demographic Data by District - House.csv"
)
congress_2020_house["Period"] = 116

# congress 2022
congress_2022_senate = pd.read_csv(
    "raw_data/117th Congress Members Guide with Election Results and Demographic Data by District - Senate.csv"
)
congress_2022_senate["Period"] = 117

congress_2022_house = pd.read_csv(
    "raw_data/117th Congress Members Guide with Election Results and Demographic Data by District - House.csv"
)
congress_2022_house["Period"] = 117


congress_senate = pd.concat([congress_2020_senate, congress_2022_senate])
congress_house = pd.concat([congress_2020_house, congress_2022_house])

# %%
congress_house["Distr"] = congress_house.Code.apply(
    lambda code: 0 if code.split("-")[1] == "AL" else code.split("-")[1]
)
congress_house["State"] = congress_house.Code.apply(
    lambda code: code.split("-")[0]
)

# %%
congress_senate.head()
# Out:
#      State  Year Class       Party First_Name  Last_Name     First Elected  \
# 0  Alabama  2017    II  Democratic       Doug      Jones      2017 Special
# 1  Alabama  2016   III  Republican    Richard     Shelby              1986
# 2   Alaska  2014    II  Republican        Dan   Sullivan              2014
# 3   Alaska  2016   III  Republican       Lisa  Murkowski  2002 Appointment
# 4  Arizona  2018     I  Democratic    Kyrsten     Sinema              2018
#
#    Birth Year Gender        Race_Ethnicity                    Religion  \
# 0        1954    Man  White - Non-Hispanic       Christian - Methodist
# 1        1934    Man  White - Non-Hispanic    Christian - Presbyterian
# 2        1964    Man  White - Non-Hispanic  Christian - Roman Catholic
# 3        1957  Woman  White - Non-Hispanic  Christian - Roman Catholic
# 4        1976  Woman  White - Non-Hispanic                Unaffiliated
#
#       LGBTQ Pre_2018_Incumbent  Period Appointed Pre_2020 Incumbent
# 0        No    Lost in primary     116       NaN                NaN
# 1        No             Not up     116       NaN                NaN
# 2        No             Not up     116       NaN                NaN
# 3        No             Not up     116       NaN                NaN
# 4  Bisexual     Open - Retired     116       NaN                NaN

# %%
# A python dictionary to abbr US states

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
congress_senate.State = congress_senate.State.apply(
    lambda x: us_state_to_abbrev[x]
)

# %%
# concatenate the senate and the house dataframes
df_bios_2020 = pd.concat([congress_senate, congress_house])

df_bios_2020.drop(["Year", "Code", "District"], inplace=True, axis=1)
df_bios_2020.rename(
    columns={"Distr": "District", "Class": "Senate Class"}, inplace=True
)

df_bios_2020.District.fillna("Senator", inplace=True)
df_bios_2020["Type"] = df_bios_2020.District.apply(
    lambda district: "sen" if district == "Senator" else "rep"
)

df_bios_2020.reset_index(inplace=True, drop=True)
df_bios_2020.Gender = df_bios_2020.Gender.apply(
    lambda gender: "M" if gender == "Man" else "F" if gender == "Woman" else gender
)

# %%
congress_data.birthday = pd.to_datetime(congress_data.birthday)
congress_data["Birth Year"] = congress_data.birthday.dt.year

# %%
congress_data[congress_data.last_name.str.contains("Manchin")]
# Out:
#       last_name first_name middle_name suffix nickname         full_name  \
# 12162   Manchin        Joe         NaN    III      NaN  Joe Manchin, III
#
#         birthday gender type state  ...  lis_id    fec_ids cspan_id  \
# 12162 1947-08-24      M  sen    WV  ...    S338  S0WV00090  62864.0
#
#       govtrack_id votesmart_id   ballotpedia_id washington_post_id icpsr_id  \
# 12162      412391       7547.0  Joe Manchin III                NaN  40915.0
#
#       wikipedia_id  Birth Year
# 12162  Joe Manchin      1947.0
#
# [1 rows x 37 columns]

# %%
# Join the historical and bios data of the congress members

matches = df_bios_2020.merge(
    congress_data,
    right_on=["last_name", "state", "type", "gender", "Birth Year"],
    left_on=["Last_Name", "State", "Type", "Gender", "Birth Year"],
    how="left",
)

new_df = matches[~matches.govtrack_id.isna()]

# %%
# merge the new dataframe with the govtract scores using govtrack ids

df_ideology = new_df.merge(
    df_2020[["ideology", "id", "bioguide_id"]],
    left_on=["govtrack_id", "bioguide_id"],
    right_on=["id", "bioguide_id"],
    how="left",
)

# %%
df_ideology
# Out:
#     State Senate Class       Party First_Name      Last_Name  \
# 0      AL           II  Democratic       Doug          Jones
# 1      AL          III  Republican    Richard         Shelby
# 2      AK           II  Republican        Dan       Sullivan
# 3      AK          III  Republican       Lisa      Murkowski
# 4      AZ            I  Democratic    Kyrsten         Sinema
# ..    ...          ...         ...        ...            ...
# 601    WI          NaN  Republican        Jim  Sensenbrenner
# 602    WI          NaN  Republican      Glenn       Grothman
# 603    WI          NaN  Republican        Tom        Tiffany
# 604    WI          NaN  Republican       Mike      Gallagher
# 605    WY          NaN  Republican        Liz         Cheney
#
#         First Elected Birth Year Gender        Race_Ethnicity  \
# 0        2017 Special       1954      M  White - Non-Hispanic
# 1                1986       1934      M  White - Non-Hispanic
# 2                2014       1964      M  White - Non-Hispanic
# 3    2002 Appointment       1957      F  White - Non-Hispanic
# 4                2018       1976      F  White - Non-Hispanic
# ..                ...        ...    ...                   ...
# 601              1978     1943.0      M  White - Non-Hispanic
# 602              2014     1955.0      M  White - Non-Hispanic
# 603      2020 Special     1957.0      M  White - Non-Hispanic
# 604              2016     1984.0      M  White - Non-Hispanic
# 605              2016     1966.0      F  White - Non-Hispanic
#
#                        Religion  ...              fec_ids   cspan_id  \
# 0         Christian - Methodist  ...            S0AL00156  1024592.0
# 1      Christian - Presbyterian  ...            S6AL00013     1859.0
# 2    Christian - Roman Catholic  ...            S4AK00214  1023262.0
# 3    Christian - Roman Catholic  ...            S4AK00099  1004138.0
# 4                  Unaffiliated  ...  H2AZ09019,S8AZ00197    68489.0
# ..                          ...  ...                  ...        ...
# 601  Christian - Roman Catholic  ...            H8WI09050     1507.0
# 602        Christian - Lutheran  ...            H4WI06048    77282.0
# 603                   Christian  ...            H0WI07101        NaN
# 604  Christian - Roman Catholic  ...            H6WI08155   104067.0
# 605       Christian - Methodist  ...            H6WY00159    86147.0
#
#      govtrack_id votesmart_id                 ballotpedia_id  \
# 0       412741.0     176464.0           Doug Jones (Alabama)
# 1       300089.0      53266.0                 Richard Shelby
# 2       412665.0     114964.0             Daniel S. Sullivan
# 3       300075.0      15841.0                 Lisa Murkowski
# 4       412509.0      28338.0                 Kyrsten Sinema
# ..           ...          ...                            ...
# 601     400365.0      27142.0              Jim Sensenbrenner
# 602     412661.0       3493.0                 Glenn Grothman
# 603     456791.0          NaN                    Tom Tiffany
# 604     412731.0     171843.0  Michael Gallagher (Wisconsin)
# 605     412732.0     171319.0                     Liz Cheney
#
#     washington_post_id icpsr_id                          wikipedia_id  \
# 0                  NaN  41705.0               Doug Jones (politician)
# 1                  NaN  94659.0                        Richard Shelby
# 2                  NaN  41500.0           Dan Sullivan (U.S. senator)
# 3                  NaN  40300.0                        Lisa Murkowski
# 4                  NaN  21300.0                        Kyrsten Sinema
# ..                 ...      ...                                   ...
# 601                NaN  14657.0                     Jim Sensenbrenner
# 602                NaN  21559.0                        Glenn Grothman
# 603                NaN      NaN                           Tom Tiffany
# 604                NaN  21720.0  Mike Gallagher (American politician)
# 605                NaN  21710.0                            Liz Cheney
#
#      ideology        id
# 0    0.632886  412741.0
# 1    0.610349  300089.0
# 2    0.714706  412665.0
# 3    0.568338  300075.0
# 4    0.675805  412509.0
# ..        ...       ...
# 601  0.621411  400365.0
# 602  0.816250  412661.0
# 603  0.578802  456791.0
# 604  0.761699  412731.0
# 605  0.678131  412732.0
#
# [606 rows x 56 columns]

# %%
def age(born):
    try:
        today = date.today()
        return (
            today.year - born.year - ((today.month, today.day) < (born.month, born.day))
        )
    except (ValueError, TypeError):
        return born  # leave unchanged


df_ideology["age"] = df_ideology.birthday.apply(age)

# %%
df_ideology = df_ideology[~df_ideology.twitter.isna()]

# %%
# save the ideology dataframe

df_ideology.to_csv("raw_data/congress_bios.csv", index=False)

# %% [markdown]
# ### Twitter data and merge with the Biography data

# %%
# read Twitter data

twitter_data = pd.read_csv("raw_data/vader_sentiment_tweets.csv")

# %%
twitter_data.head(5)
# Out:
#               tweet_id       username party  \
# 0  1453097115664662536  RepMikeGarcia     R
# 1  1511713375218245640   RepGallagher     R
# 2  1381021863313350658      RepDLesko     R
# 3  1362468292569534465  RepDebDingell     D
# 4  1551368623142363138    RepCarbajal     D
#
#                                                tweet  \
# 0  I joined fellow China Task Force lawmakers in ...
# 1  Rep. Gallagher: "If we do not invest in hard p...
# 2  CBP is currently encountering over 5,000 peopl...
# 3  It’s past time our country ban discrimination ...
# 4  Proud to present the Woman of the Year Award t...
#
#                                           clean_text  favorite_count  \
# 0   joined fellow china task force lawmakers in s...              43
# 1  rep gallagher if we do not invest in hard powe...              25
# 2  cbp is currently encountering over 000 people ...             283
# 3  it is past time our country ban discrimination...              92
# 4  proud to present the woman of the year award t...              17
#
#    retweet_count                 created_at              source  \
# 0             29  2021-10-26 20:32:04+00:00     Twitter Web App
# 1             11  2022-04-06 14:32:09+00:00     Twitter Web App
# 2             82  2021-04-10 23:10:45+00:00  Twitter for iPhone
# 3             21  2021-02-18 18:25:29+00:00     Twitter Web App
# 4              1  2022-07-25 00:47:57+00:00  Twitter for iPhone
#
#      social_policy  ...  rank score govtrack_cluster progressive_cluster  \
# 0              NaN  ...  #218  0.44                2                   3
# 1              NaN  ...   #52  0.76                4                   4
# 2  Social Policies  ...    #7  0.91                4                   4
# 3  Social Policies  ...  #351  0.25                1                   0
# 4  Social Policies  ...  #283  0.32                1                   0
#
#   govtrack_class  positive_sentiment neutral_sentiment negative_sentiment  \
# 0       Centrist            0.000001          0.807001           0.193001
# 1      Far Right            0.113001          0.786001           0.101001
# 2      Far Right            0.029001          0.860001           0.110001
# 3  Left Centrist            0.086001          0.799001           0.115001
# 4  Left Centrist            0.329001          0.671001           0.000001
#
#    compound_sentiment  sentiment_text
# 0           -0.771699        negative
# 1           -0.128999        negative
# 2           -0.678299        negative
# 3           -0.226299        negative
# 4            0.940301        positive
#
# [5 rows x 27 columns]

# %%
# merge the the biographies with the twitter dataset on username

df = twitter_data.merge(df_ideology, left_on="username", right_on="twitter", how="left")

df.Party = df.Party.apply(
    lambda party: "R"
    if party == "Republican"
    else "D"
    if party == "Democratic"
    else "I"
    if party == "Independent"
    else party
)

# %%
df = df[~df.govtrack_id.isna()]

# %%
# include the military and religion

# df = df.merge(df_religion_2020[["Last_Name", "District", "State", "Party", "Military"]], on=["State", "Last_Name", "District", "Party"], how="left")
# df.Military = df["Military"].fillna("No")

# %% [markdown]
# ## **Multiple Regression Test**
#
# The 2020 Congress report data used in this section.
# <br />
# The output of the model is the sentiment of the tweet whereas the independent variables
# are the ideology score, age, gender identity (LGBTQ), religion and military history of the legislator.

# %%
import statsmodels.formula.api as smf
import numpy as np

# %%
def model(data):
    "model"
    mod = smf.ols(
        formula="compound_sentiment ~ ideology + Party + LGBTQ + Gender + Religion + Race_Ethnicity + age",
        data=data,
    )

    return mod.fit()

# %%
df = pd.read_csv("vader_sentiment_tweets.csv")

# %%
christian_categories = {
    "Christian": "Christian",
    "Christian - Roman Catholic": "Christian",
    "Christian - Baptist": "Christian",
    "Christian - Mormon": "Christian",
    "Hindu": "Hindu",
    "Jewish": "Jewish",
    "Christian - Catholic":"Christian",
    "Christian - Evangelical Protestant": "Christian",
    "Christian - Church of God": "Christian",
    "Unknown/Refused": "Unknown",
    "Unaffiliated": "Unaffiliated",
    "Christian - Presbyterian": "Christian",
    "Christian - Methodist": "Christian",
    "Christian - Lutheran": "Christian",
    "Christian - Episcopalian": "Christian",
    "Christian - Southern Baptist": "Christian",
    "Christian - Protestant": "Christian",
    "Christian - Restorationist": "Christian",
    "Christian - Disciples of Christ": "Christian",
    "Christian - Nondenominational": "Christian",
    "Unitarian Universalist": "Christian",
    "Christian - Eastern Orthodox": "Orthodox",
    "Christian - Evangelical Free Church": "Christian",
    "Christian - Pentecostal": "Christian",
    "Christian - Seventh-Day Adventist": "Christian",
    "Christian - Nondenominational Protestant": "Christian",
    "Buddhist - Soka Gakkai": "Buddhist",
    "Muslim": "Muslim",
    "Christian - African Methodist Episcopal": "Christian",
    "Christian - Chaldean Catholic": "Christian",
    "Christian - Congregationalist": "Christian",
    "Christian - United Brethren": "Christian",
    "Christian - Reformed (Calvinist)": "Christian",
}

# %%
ethnicity = {
    "Hispanic - Mexican": "Hispanic",
    "White - Non-Hispanic": "White",
    "Asian - Thai": "Asian",
    "Asian - Indian": "Asian",
    "Black - African-American": "Black",
    "Black - African-American/Asian - Filipino": "Black",
    "Hispanic": "Hispanic",
    "Hispanic - Puerto Rican": "Hispanic",
    "White - Portuguese-American": "White",
    "Native American - Chickasaw": "Native American",
    "Black - Jamaican": "Black",
    "Hispanic - Mexican / Jewish": "Hispanic",
    "Hispanic - Cuban": "Hispanic",
    "Asian - Korean": "Asian",
    "Hispanic - Dominican": "Hispanic",
    "Black - Eritrean": "Black",
    "Black - African-American/Trinidadian": "Black",
    "Hispanic - Mexican/Colombian": "Hispanic",
    "Asian - Chinese": "Asian",
    "Asian - Japanese": "Asian",
    "Hispanic - Guatemalan": "Hispanic",
    "Asian - Taiwanese": "Asian",
    "Native American - Ho-Chunk": "Native American",
    "White - Middle Eastern - Lebanese": "White",
    "White - Middle Eastern - Palestinian": "White",
}

# %%
#  collapse religion and ethnicity

df["Religion"] = df.Religion.apply(lambda x: christian_categories[x])
df["Race_Ethnicity"] = df.Race_Ethnicity.apply(lambda x: ethnicity[x])

# %%
res = model(df)

# %%
df.Party.unique()
# Out:
# array(['Democratic', 'Republican', 'Independent - Dem Caucus'],
#       dtype=object)

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     84.31
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        14:09:09   Log-Likelihood:            -1.4273e+05
# No. Observations:              151338   AIC:                         2.855e+05
# Df Residuals:                  151318   BIC:                         2.857e+05
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -2.594e+09   2.39e+09     -1.085      0.278   -7.28e+09    2.09e+09
# Party[T.Independent - Dem Caucus]    -0.0119      0.020     -0.589      0.556      -0.052       0.028
# Party[T.Republican]                  -0.2274      0.008    -27.080      0.000      -0.244      -0.211
# LGBTQ[T.Gay]                       2.594e+09   2.39e+09      1.085      0.278   -2.09e+09    7.28e+09
# LGBTQ[T.Lesbian]                   2.594e+09   2.39e+09      1.085      0.278   -2.09e+09    7.28e+09
# LGBTQ[T.No]                        2.594e+09   2.39e+09      1.085      0.278   -2.09e+09    7.28e+09
# Gender[T.M]                          -0.0079      0.004     -2.030      0.042      -0.016      -0.000
# Religion[T.Christian]                -0.0276      0.034     -0.815      0.415      -0.094       0.039
# Religion[T.Hindu]                    -0.1613      0.039     -4.114      0.000      -0.238      -0.084
# Religion[T.Jewish]                   -0.0850      0.034     -2.469      0.014      -0.152      -0.018
# Religion[T.Muslim]                   -0.1479      0.043     -3.468      0.001      -0.231      -0.064
# Religion[T.Orthodox]                  0.0924      0.039      2.378      0.017       0.016       0.169
# Religion[T.Unaffiliated]           2.594e+09   2.39e+09      1.085      0.278   -2.09e+09    7.28e+09
# Religion[T.Unknown]                  -0.0541      0.035     -1.545      0.122      -0.123       0.015
# Race_Ethnicity[T.Black]              -0.0941      0.014     -6.612      0.000      -0.122      -0.066
# Race_Ethnicity[T.Hispanic]           -0.0574      0.014     -4.147      0.000      -0.085      -0.030
# Race_Ethnicity[T.Native American]     0.0863      0.039      2.211      0.027       0.010       0.163
# Race_Ethnicity[T.White]              -0.0138      0.013     -1.065      0.287      -0.039       0.012
# ideology                              0.2365      0.015     15.790      0.000       0.207       0.266
# age                                  -0.0016      0.000    -10.443      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                  1529439.432   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12366.920
# Skew:                          -0.091   Prob(JB):                         0.00
# Kurtosis:                       1.611   Cond. No.                     2.12e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.35e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# regression tests per policy

import json
import string

# open json file consisting of policies and its sub-groups
with open("data.json") as json_file:
    categories = json.load(json_file)

# %%
articles = ["and", "LGBTQ", "the", "of", "CHIPS", "Ukraine-Russia"]

# policies
policies = {**categories["Geo Political Policies"], **categories["Social Policies"]}
policies = list(policies.keys())
policies.remove("All")


for policy in sorted(policies, key=lambda x: x.lower()):
    str_list = string.ascii_uppercase

    title = " ".join(
        [
            word.capitalize() if word not in articles else word
            for word in policy.split(" ")
        ]
    )

    try:
        # category df
        cat_df = df[df.policies.str.contains(r"%s" % policy, re.I, regex=True)]

        res = model(cat_df)

        print(title)
        print(res.summary())
        print(" ")
    except ValueError:
        pass
# Out:
# Abortion
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     6.135
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           1.89e-14
# Time:                        14:09:11   Log-Likelihood:                -6029.2
# No. Observations:                6741   AIC:                         1.209e+04
# Df Residuals:                    6723   BIC:                         1.222e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.6327      0.174      3.636      0.000       0.292       0.974
# Party[T.Independent - Dem Caucus]    -0.1921      0.122     -1.579      0.114      -0.431       0.046
# Party[T.Republican]                   0.1662      0.046      3.577      0.000       0.075       0.257
# LGBTQ[T.Lesbian]                      0.1162      0.101      1.148      0.251      -0.082       0.315
# LGBTQ[T.No]                           0.0224      0.066      0.339      0.735      -0.107       0.152
# Gender[T.M]                          -0.0209      0.016     -1.272      0.204      -0.053       0.011
# Religion[T.Christian]                -0.1987      0.146     -1.360      0.174      -0.485       0.088
# Religion[T.Hindu]                    -0.4094      0.175     -2.339      0.019      -0.753      -0.066
# Religion[T.Jewish]                   -0.2304      0.148     -1.557      0.119      -0.520       0.060
# Religion[T.Muslim]                   -0.4122      0.170     -2.419      0.016      -0.746      -0.078
# Religion[T.Orthodox]                  0.1456      0.165      0.881      0.379      -0.179       0.470
# Religion[T.Unknown]                  -0.2265      0.151     -1.501      0.133      -0.522       0.069
# Race_Ethnicity[T.Black]               0.0352      0.049      0.717      0.473      -0.061       0.132
# Race_Ethnicity[T.Hispanic]           -0.0507      0.051     -0.996      0.320      -0.151       0.049
# Race_Ethnicity[T.Native American]     0.1437      0.194      0.742      0.458      -0.236       0.523
# Race_Ethnicity[T.White]              -0.0229      0.045     -0.509      0.611      -0.111       0.065
# ideology                             -0.3900      0.079     -4.947      0.000      -0.545      -0.235
# age                                  -0.0024      0.001     -3.139      0.002      -0.004      -0.001
# ==============================================================================
# Omnibus:                     6045.697   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              559.287
# Skew:                          -0.370   Prob(JB):                    3.57e-122
# Kurtosis:                       1.798   Cond. No.                     3.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Broadband Internet
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     2.730
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           0.000106
# Time:                        14:09:11   Log-Likelihood:                -3910.5
# No. Observations:                6624   AIC:                             7859.
# Df Residuals:                    6605   BIC:                             7988.
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.3158      0.069      4.608      0.000       0.181       0.450
# Party[T.Independent - Dem Caucus]     0.1100      0.051      2.143      0.032       0.009       0.211
# Party[T.Republican]                  -0.0623      0.024     -2.568      0.010      -0.110      -0.015
# LGBTQ[T.Gay]                          0.0251      0.068      0.368      0.713      -0.109       0.159
# LGBTQ[T.Lesbian]                      0.1017      0.051      1.993      0.046       0.002       0.202
# LGBTQ[T.No]                           0.0287      0.042      0.679      0.497      -0.054       0.112
# Gender[T.M]                          -0.0159      0.012     -1.287      0.198      -0.040       0.008
# Religion[T.Christian]                 0.1019      0.088      1.160      0.246      -0.070       0.274
# Religion[T.Hindu]                     0.1147      0.137      0.837      0.403      -0.154       0.383
# Religion[T.Jewish]                    0.0994      0.090      1.103      0.270      -0.077       0.276
# Religion[T.Muslim]                    0.0085      0.159      0.054      0.957      -0.302       0.319
# Religion[T.Orthodox]                  0.1943      0.112      1.738      0.082      -0.025       0.414
# Religion[T.Unaffiliated]              0.1603      0.072      2.218      0.027       0.019       0.302
# Religion[T.Unknown]                   0.1133      0.091      1.239      0.216      -0.066       0.293
# Race_Ethnicity[T.Black]              -0.0017      0.042     -0.040      0.968      -0.084       0.081
# Race_Ethnicity[T.Hispanic]            0.0059      0.044      0.133      0.894      -0.081       0.093
# Race_Ethnicity[T.Native American]    -0.0015      0.101     -0.015      0.988      -0.199       0.196
# Race_Ethnicity[T.White]               0.0254      0.039      0.647      0.518      -0.052       0.102
# ideology                              0.1273      0.049      2.579      0.010       0.031       0.224
# age                                  -0.0012      0.001     -2.346      0.019      -0.002      -0.000
# ==============================================================================
# Omnibus:                      773.372   Durbin-Watson:                   2.036
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1073.266
# Skew:                          -0.980   Prob(JB):                    8.77e-234
# Kurtosis:                       3.223   Cond. No.                     4.22e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.51e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Chinese Communist Party
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.662
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           1.10e-13
# Time:                        14:09:12   Log-Likelihood:                -14863.
# No. Observations:               17937   AIC:                         2.976e+04
# Df Residuals:                   17918   BIC:                         2.991e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.2090      0.166      1.258      0.208      -0.117       0.535
# Party[T.Independent - Dem Caucus]    -0.0043      0.077     -0.055      0.956      -0.156       0.147
# Party[T.Republican]                  -0.0841      0.023     -3.646      0.000      -0.129      -0.039
# LGBTQ[T.Gay]                         -0.1934      0.140     -1.381      0.167      -0.468       0.081
# LGBTQ[T.Lesbian]                     -0.1957      0.138     -1.417      0.156      -0.466       0.075
# LGBTQ[T.No]                          -0.1325      0.124     -1.065      0.287      -0.376       0.111
# Gender[T.M]                           0.0112      0.013      0.863      0.388      -0.014       0.037
# Religion[T.Christian]                 0.1762      0.230      0.766      0.444      -0.275       0.627
# Religion[T.Hindu]                     0.0667      0.239      0.279      0.780      -0.401       0.535
# Religion[T.Jewish]                    0.0637      0.231      0.275      0.783      -0.390       0.517
# Religion[T.Muslim]                    0.0924      0.263      0.351      0.726      -0.424       0.609
# Religion[T.Orthodox]                  0.2227      0.240      0.927      0.354      -0.248       0.693
# Religion[T.Unaffiliated]              0.7306      0.344      2.122      0.034       0.056       1.405
# Religion[T.Unknown]                   0.0444      0.234      0.189      0.850      -0.414       0.503
# Race_Ethnicity[T.Black]              -0.1185      0.065     -1.809      0.070      -0.247       0.010
# Race_Ethnicity[T.Hispanic]           -0.2019      0.054     -3.741      0.000      -0.308      -0.096
# Race_Ethnicity[T.Native American]     0.2595      0.104      2.504      0.012       0.056       0.463
# Race_Ethnicity[T.White]              -0.1100      0.052     -2.117      0.034      -0.212      -0.008
# ideology                              0.0383      0.038      1.002      0.316      -0.037       0.113
# age                                  -0.0002      0.000     -0.501      0.616      -0.001       0.001
# ==============================================================================
# Omnibus:                    15326.379   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1181.416
# Skew:                          -0.193   Prob(JB):                    2.88e-257
# Kurtosis:                       1.804   Cond. No.                     4.78e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.91e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# CHIPS and Science Act
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.053
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     5.057
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           2.17e-11
# Time:                        14:09:12   Log-Likelihood:                -979.55
# No. Observations:                1660   AIC:                             1997.
# Df Residuals:                    1641   BIC:                             2100.
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.2095      0.284      0.739      0.460      -0.347       0.766
# Party[T.Independent - Dem Caucus]     0.0353      0.182      0.194      0.846      -0.322       0.392
# Party[T.Republican]                  -0.2095      0.060     -3.470      0.001      -0.328      -0.091
# LGBTQ[T.Gay]                         -0.3347      0.217     -1.544      0.123      -0.760       0.090
# LGBTQ[T.Lesbian]                      0.2210      0.207      1.069      0.285      -0.184       0.626
# LGBTQ[T.No]                          -0.0162      0.184     -0.088      0.930      -0.377       0.344
# Gender[T.M]                           0.0615      0.026      2.392      0.017       0.011       0.112
# Religion[T.Christian]                 0.2236      0.442      0.506      0.613      -0.643       1.090
# Religion[T.Hindu]                     0.0764      0.454      0.168      0.867      -0.815       0.968
# Religion[T.Jewish]                    0.1322      0.443      0.298      0.765      -0.737       1.001
# Religion[T.Muslim]                   -0.2091      0.624     -0.335      0.738      -1.434       1.015
# Religion[T.Orthodox]                  0.5237      0.494      1.060      0.289      -0.445       1.492
# Religion[T.Unaffiliated]              0.3395      0.282      1.203      0.229      -0.214       0.893
# Religion[T.Unknown]                   0.2764      0.445      0.621      0.535      -0.597       1.149
# Race_Ethnicity[T.Black]               0.0034      0.090      0.038      0.970      -0.173       0.179
# Race_Ethnicity[T.Hispanic]            0.1271      0.087      1.466      0.143      -0.043       0.297
# Race_Ethnicity[T.Native American]    -0.0805      0.177     -0.456      0.649      -0.427       0.266
# Race_Ethnicity[T.White]               0.0236      0.077      0.306      0.760      -0.128       0.175
# ideology                             -0.0237      0.120     -0.198      0.843      -0.259       0.211
# age                                   0.0006      0.001      0.592      0.554      -0.001       0.003
# ==============================================================================
# Omnibus:                      234.653   Durbin-Watson:                   2.055
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              340.353
# Skew:                          -1.089   Prob(JB):                     1.24e-74
# Kurtosis:                       3.420   Cond. No.                     2.35e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.17e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Climate Change
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     30.77
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):          1.01e-104
# Time:                        14:09:12   Log-Likelihood:                -20471.
# No. Observations:               23181   AIC:                         4.098e+04
# Df Residuals:                   23162   BIC:                         4.113e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1538      0.068      2.251      0.024       0.020       0.288
# Party[T.Independent - Dem Caucus]    -0.1759      0.032     -5.473      0.000      -0.239      -0.113
# Party[T.Republican]                  -0.3099      0.024    -13.013      0.000      -0.357      -0.263
# LGBTQ[T.Gay]                         -0.1022      0.058     -1.767      0.077      -0.216       0.011
# LGBTQ[T.Lesbian]                      0.1074      0.059      1.833      0.067      -0.007       0.222
# LGBTQ[T.No]                           0.0020      0.048      0.042      0.966      -0.092       0.096
# Gender[T.M]                          -0.0286      0.009     -3.069      0.002      -0.047      -0.010
# Religion[T.Christian]                -0.0563      0.080     -0.706      0.480      -0.213       0.100
# Religion[T.Hindu]                    -0.3693      0.092     -3.997      0.000      -0.550      -0.188
# Religion[T.Jewish]                   -0.0346      0.081     -0.428      0.669      -0.193       0.124
# Religion[T.Muslim]                   -0.1859      0.101     -1.836      0.066      -0.384       0.013
# Religion[T.Orthodox]                  0.2214      0.091      2.428      0.015       0.043       0.400
# Religion[T.Unaffiliated]              0.1466      0.136      1.079      0.281      -0.120       0.413
# Religion[T.Unknown]                  -0.0463      0.081     -0.570      0.569      -0.206       0.113
# Race_Ethnicity[T.Black]              -0.0519      0.037     -1.393      0.164      -0.125       0.021
# Race_Ethnicity[T.Hispanic]           -0.0907      0.036     -2.533      0.011      -0.161      -0.021
# Race_Ethnicity[T.Native American]     0.0842      0.124      0.681      0.496      -0.158       0.327
# Race_Ethnicity[T.White]              -0.1396      0.033     -4.213      0.000      -0.205      -0.075
# ideology                              0.6770      0.040     17.083      0.000       0.599       0.755
# age                                   0.0008      0.000      1.994      0.046    1.43e-05       0.002
# ==============================================================================
# Omnibus:                    17657.430   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1868.916
# Skew:                          -0.368   Prob(JB):                         0.00
# Kurtosis:                       1.820   Cond. No.                     5.27e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.47e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Fossil Fuels
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     5.953
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           1.26e-14
# Time:                        14:09:13   Log-Likelihood:                -10540.
# No. Observations:               12322   AIC:                         2.112e+04
# Df Residuals:                   12303   BIC:                         2.126e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0705      0.111      0.634      0.526      -0.148       0.289
# Party[T.Independent - Dem Caucus]     0.0006      0.045      0.013      0.989      -0.087       0.089
# Party[T.Republican]                  -0.0783      0.029     -2.673      0.008      -0.136      -0.021
# LGBTQ[T.Gay]                          0.1453      0.101      1.438      0.150      -0.053       0.343
# LGBTQ[T.Lesbian]                      0.2912      0.093      3.139      0.002       0.109       0.473
# LGBTQ[T.No]                           0.0105      0.079      0.134      0.894      -0.144       0.165
# Gender[T.M]                          -0.0349      0.015     -2.389      0.017      -0.064      -0.006
# Religion[T.Christian]                 0.0055      0.132      0.042      0.967      -0.253       0.264
# Religion[T.Hindu]                    -0.0660      0.151     -0.438      0.661      -0.361       0.229
# Religion[T.Jewish]                   -0.0021      0.134     -0.016      0.987      -0.264       0.260
# Religion[T.Muslim]                   -0.2898      0.151     -1.918      0.055      -0.586       0.006
# Religion[T.Orthodox]                  0.0569      0.145      0.391      0.696      -0.228       0.342
# Religion[T.Unaffiliated]             -0.3765      0.221     -1.703      0.089      -0.810       0.057
# Religion[T.Unknown]                   0.0666      0.134      0.496      0.620      -0.196       0.329
# Race_Ethnicity[T.Black]               0.0233      0.069      0.340      0.734      -0.111       0.158
# Race_Ethnicity[T.Hispanic]            0.0276      0.064      0.434      0.664      -0.097       0.152
# Race_Ethnicity[T.Native American]    -0.2883      0.118     -2.449      0.014      -0.519      -0.058
# Race_Ethnicity[T.White]               0.0029      0.060      0.048      0.962      -0.116       0.121
# ideology                              0.1750      0.049      3.568      0.000       0.079       0.271
# age                                  -0.0012      0.001     -2.099      0.036      -0.002   -7.87e-05
# ==============================================================================
# Omnibus:                    26118.514   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              844.802
# Skew:                          -0.076   Prob(JB):                    3.58e-184
# Kurtosis:                       1.726   Cond. No.                     8.00e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.83e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Gun Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     45.55
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):          8.81e-160
# Time:                        14:09:13   Log-Likelihood:                -23513.
# No. Observations:               25724   AIC:                         4.706e+04
# Df Residuals:                   25705   BIC:                         4.722e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.3465      0.051     -6.834      0.000      -0.446      -0.247
# Party[T.Independent - Dem Caucus]     0.0461      0.055      0.835      0.404      -0.062       0.154
# Party[T.Republican]                   0.0610      0.021      2.949      0.003       0.020       0.102
# LGBTQ[T.Gay]                         -0.0768      0.044     -1.756      0.079      -0.162       0.009
# LGBTQ[T.Lesbian]                      0.1602      0.047      3.420      0.001       0.068       0.252
# LGBTQ[T.No]                          -0.0547      0.035     -1.574      0.116      -0.123       0.013
# Gender[T.M]                           0.0094      0.009      1.097      0.273      -0.007       0.026
# Religion[T.Christian]                 0.0132      0.058      0.228      0.820      -0.100       0.126
# Religion[T.Hindu]                    -0.0149      0.072     -0.207      0.836      -0.156       0.126
# Religion[T.Jewish]                    0.0076      0.059      0.129      0.898      -0.108       0.123
# Religion[T.Muslim]                   -0.1367      0.076     -1.789      0.074      -0.286       0.013
# Religion[T.Orthodox]                  0.1440      0.075      1.927      0.054      -0.002       0.291
# Religion[T.Unaffiliated]             -0.3752      0.094     -3.975      0.000      -0.560      -0.190
# Religion[T.Unknown]                  -0.0119      0.061     -0.196      0.845      -0.131       0.107
# Race_Ethnicity[T.Black]               0.0149      0.028      0.530      0.596      -0.040       0.070
# Race_Ethnicity[T.Hispanic]            0.0099      0.029      0.347      0.729      -0.046       0.066
# Race_Ethnicity[T.Native American]     0.2007      0.127      1.586      0.113      -0.047       0.449
# Race_Ethnicity[T.White]               0.0844      0.026      3.190      0.001       0.033       0.136
# ideology                              0.2607      0.038      6.932      0.000       0.187       0.334
# age                                  -0.0018      0.000     -4.935      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                     4629.745   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2938.584
# Skew:                           0.708   Prob(JB):                         0.00
# Kurtosis:                       2.143   Cond. No.                     6.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.55e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Immigration and Border Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     130.5
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        14:09:14   Log-Likelihood:                -30444.
# No. Observations:               33839   AIC:                         6.093e+04
# Df Residuals:                   33820   BIC:                         6.109e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1890      0.055      3.406      0.001       0.080       0.298
# Party[T.Independent - Dem Caucus]    -0.1506      0.069     -2.187      0.029      -0.286      -0.016
# Party[T.Republican]                  -0.4222      0.018    -23.965      0.000      -0.457      -0.388
# LGBTQ[T.Gay]                         -0.0725      0.048     -1.496      0.135      -0.167       0.022
# LGBTQ[T.Lesbian]                      0.2181      0.089      2.462      0.014       0.044       0.392
# LGBTQ[T.No]                           0.0633      0.039      1.627      0.104      -0.013       0.139
# Gender[T.M]                           0.0004      0.008      0.051      0.959      -0.016       0.017
# Religion[T.Christian]                -0.1310      0.071     -1.839      0.066      -0.271       0.009
# Religion[T.Hindu]                    -0.0588      0.099     -0.595      0.552      -0.252       0.135
# Religion[T.Jewish]                   -0.2152      0.073     -2.944      0.003      -0.358      -0.072
# Religion[T.Muslim]                   -0.2497      0.092     -2.710      0.007      -0.430      -0.069
# Religion[T.Orthodox]                 -0.1419      0.083     -1.712      0.087      -0.304       0.021
# Religion[T.Unaffiliated]             -0.0198      0.061     -0.324      0.746      -0.140       0.100
# Religion[T.Unknown]                  -0.1711      0.077     -2.221      0.026      -0.322      -0.020
# Race_Ethnicity[T.Black]              -0.0086      0.034     -0.257      0.798      -0.075       0.057
# Race_Ethnicity[T.Hispanic]           -0.0019      0.031     -0.062      0.951      -0.063       0.059
# Race_Ethnicity[T.Native American]     0.1228      0.093      1.315      0.189      -0.060       0.306
# Race_Ethnicity[T.White]               0.0486      0.030      1.596      0.110      -0.011       0.108
# ideology                              0.1269      0.030      4.263      0.000       0.069       0.185
# age                                  -0.0006      0.000     -1.985      0.047      -0.001   -7.97e-06
# ==============================================================================
# Omnibus:                    37850.412   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2240.291
# Skew:                           0.152   Prob(JB):                         0.00
# Kurtosis:                       1.777   Cond. No.                     1.14e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  1e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# LGBTQ Community
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     3.400
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           1.42e-06
# Time:                        14:09:14   Log-Likelihood:                -6033.2
# No. Observations:                6073   AIC:                         1.210e+04
# Df Residuals:                    6054   BIC:                         1.223e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0841      0.121      0.697      0.486      -0.152       0.321
# Party[T.Independent - Dem Caucus]    -0.0867      0.183     -0.473      0.636      -0.446       0.273
# Party[T.Republican]                  -0.1016      0.088     -1.151      0.250      -0.275       0.071
# LGBTQ[T.Gay]                         -0.1234      0.090     -1.364      0.173      -0.301       0.054
# LGBTQ[T.Lesbian]                      0.0853      0.094      0.910      0.363      -0.098       0.269
# LGBTQ[T.No]                          -0.0862      0.086     -1.008      0.313      -0.254       0.081
# Gender[T.M]                          -0.0003      0.018     -0.018      0.986      -0.036       0.036
# Religion[T.Christian]                 0.2030      0.142      1.431      0.153      -0.075       0.481
# Religion[T.Hindu]                     0.0451      0.161      0.281      0.779      -0.270       0.360
# Religion[T.Jewish]                    0.1869      0.144      1.296      0.195      -0.096       0.470
# Religion[T.Muslim]                    0.1891      0.159      1.186      0.236      -0.123       0.502
# Religion[T.Orthodox]                  0.3874      0.163      2.370      0.018       0.067       0.708
# Religion[T.Unaffiliated]              0.2085      0.253      0.825      0.409      -0.287       0.704
# Religion[T.Unknown]                   0.1391      0.145      0.956      0.339      -0.146       0.424
# Race_Ethnicity[T.Black]               0.0445      0.047      0.937      0.349      -0.049       0.138
# Race_Ethnicity[T.Hispanic]            0.0106      0.048      0.221      0.825      -0.084       0.105
# Race_Ethnicity[T.Native American]    -0.0915      0.178     -0.515      0.606      -0.440       0.257
# Race_Ethnicity[T.White]              -0.0085      0.043     -0.198      0.843      -0.093       0.076
# ideology                              0.3434      0.093      3.703      0.000       0.162       0.525
# age                                  -0.0014      0.001     -1.588      0.112      -0.003       0.000
# ==============================================================================
# Omnibus:                     9041.504   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              622.923
# Skew:                          -0.474   Prob(JB):                    5.42e-136
# Kurtosis:                       1.750   Cond. No.                     2.53e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.71e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Substance Abuse and Mental Health
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     9.875
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           4.72e-28
# Time:                        14:09:15   Log-Likelihood:                -11414.
# No. Observations:               11474   AIC:                         2.287e+04
# Df Residuals:                   11455   BIC:                         2.301e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.0584      0.092     -0.634      0.526      -0.239       0.122
# Party[T.Independent - Dem Caucus]    -0.1603      0.081     -1.989      0.047      -0.318      -0.002
# Party[T.Republican]                  -0.3113      0.030    -10.336      0.000      -0.370      -0.252
# LGBTQ[T.Gay]                         -0.1111      0.073     -1.532      0.126      -0.253       0.031
# LGBTQ[T.Lesbian]                      0.0809      0.066      1.220      0.222      -0.049       0.211
# LGBTQ[T.No]                           0.0441      0.058      0.766      0.444      -0.069       0.157
# Gender[T.M]                          -0.0316      0.014     -2.252      0.024      -0.059      -0.004
# Religion[T.Christian]                 0.0927      0.128      0.723      0.470      -0.159       0.344
# Religion[T.Hindu]                     0.1682      0.149      1.127      0.260      -0.124       0.461
# Religion[T.Jewish]                    0.0901      0.130      0.695      0.487      -0.164       0.344
# Religion[T.Muslim]                    0.0699      0.169      0.414      0.679      -0.261       0.401
# Religion[T.Orthodox]                  0.2405      0.137      1.756      0.079      -0.028       0.509
# Religion[T.Unaffiliated]             -0.0723      0.095     -0.759      0.448      -0.259       0.114
# Religion[T.Unknown]                   0.1201      0.131      0.913      0.361      -0.138       0.378
# Race_Ethnicity[T.Black]              -0.0719      0.048     -1.509      0.131      -0.165       0.021
# Race_Ethnicity[T.Hispanic]           -0.1125      0.048     -2.343      0.019      -0.207      -0.018
# Race_Ethnicity[T.Native American]     0.0122      0.104      0.117      0.907      -0.191       0.216
# Race_Ethnicity[T.White]              -0.0793      0.043     -1.828      0.068      -0.164       0.006
# ideology                              0.4702      0.059      7.918      0.000       0.354       0.587
# age                               -6.619e-05      0.001     -0.113      0.910      -0.001       0.001
# ==============================================================================
# Omnibus:                    90738.125   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1083.369
# Skew:                          -0.236   Prob(JB):                    5.62e-236
# Kurtosis:                       1.571   Cond. No.                     4.63e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.1e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Taiwan
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     6.804
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           8.01e-14
# Time:                        14:09:15   Log-Likelihood:                -1922.0
# No. Observations:                2302   AIC:                             3874.
# Df Residuals:                    2287   BIC:                             3960.
# Df Model:                          14
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.3659      0.406      0.901      0.368      -0.430       1.162
# Party[T.Independent - Dem Caucus]    -0.2914      0.244     -1.193      0.233      -0.770       0.188
# Party[T.Republican]                   0.0075      0.076      0.098      0.922      -0.141       0.156
# LGBTQ[T.No]                           0.2322      0.404      0.575      0.565      -0.560       1.024
# Gender[T.M]                          -0.0841      0.043     -1.966      0.049      -0.168      -0.000
# Religion[T.Hindu]                    -0.3505      0.103     -3.406      0.001      -0.552      -0.149
# Religion[T.Jewish]                   -0.2177      0.085     -2.556      0.011      -0.385      -0.051
# Religion[T.Orthodox]                  0.7060      0.396      1.783      0.075      -0.070       1.482
# Religion[T.Unknown]                   0.0016      0.163      0.010      0.992      -0.317       0.320
# Race_Ethnicity[T.Black]               0.0663      0.127      0.522      0.601      -0.182       0.315
# Race_Ethnicity[T.Hispanic]           -0.1852      0.095     -1.952      0.051      -0.371       0.001
# Race_Ethnicity[T.Native American]     0.0358      0.294      0.122      0.903      -0.541       0.613
# Race_Ethnicity[T.White]              -0.1988      0.087     -2.277      0.023      -0.370      -0.028
# ideology                             -0.4230      0.121     -3.500      0.000      -0.660      -0.186
# age                                   0.0036      0.001      3.215      0.001       0.001       0.006
# ==============================================================================
# Omnibus:                      434.885   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              174.790
# Skew:                          -0.491   Prob(JB):                     1.11e-38
# Kurtosis:                       2.074   Cond. No.                     2.95e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Ukraine-Russia
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     9.341
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):           2.69e-26
# Time:                        14:09:15   Log-Likelihood:                -20945.
# No. Observations:               23887   AIC:                         4.193e+04
# Df Residuals:                   23868   BIC:                         4.208e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1742      0.114      1.531      0.126      -0.049       0.397
# Party[T.Independent - Dem Caucus]     0.0358      0.048      0.749      0.454      -0.058       0.129
# Party[T.Republican]                  -0.0850      0.020     -4.291      0.000      -0.124      -0.046
# LGBTQ[T.Gay]                          0.0446      0.087      0.510      0.610      -0.127       0.216
# LGBTQ[T.Lesbian]                      0.1066      0.095      1.124      0.261      -0.079       0.292
# LGBTQ[T.No]                           0.0428      0.077      0.559      0.576      -0.107       0.193
# Gender[T.M]                          -0.0627      0.010     -5.976      0.000      -0.083      -0.042
# Religion[T.Christian]                 0.0404      0.169      0.239      0.811      -0.291       0.372
# Religion[T.Hindu]                    -0.1798      0.177     -1.018      0.309      -0.526       0.166
# Religion[T.Jewish]                   -0.0205      0.170     -0.121      0.904      -0.353       0.312
# Religion[T.Muslim]                    0.1333      0.194      0.687      0.492      -0.247       0.514
# Religion[T.Orthodox]                  0.1461      0.179      0.818      0.413      -0.204       0.496
# Religion[T.Unaffiliated]             -0.0198      0.152     -0.131      0.896      -0.317       0.277
# Religion[T.Unknown]                  -0.0188      0.171     -0.109      0.913      -0.355       0.317
# Race_Ethnicity[T.Black]              -0.1549      0.048     -3.226      0.001      -0.249      -0.061
# Race_Ethnicity[T.Hispanic]           -0.1679      0.047     -3.595      0.000      -0.259      -0.076
# Race_Ethnicity[T.Native American]    -0.1743      0.100     -1.747      0.081      -0.370       0.021
# Race_Ethnicity[T.White]              -0.1181      0.044     -2.669      0.008      -0.205      -0.031
# ideology                              0.0231      0.035      0.658      0.511      -0.046       0.092
# age                                  -0.0006      0.000     -1.720      0.085      -0.001    8.91e-05
# ==============================================================================
# Omnibus:                    84085.420   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1676.619
# Skew:                          -0.018   Prob(JB):                         0.00
# Kurtosis:                       1.703   Cond. No.                     1.89e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.75e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
