# %%
# %load_ext jupyter_black
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
import re
import json
import time
import requests
from datetime import datetime, date

from selenium import webdriver
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
from bs4 import BeautifulSoup
import tabula
import pandas as pd

# %% [markdown]
# ## The Govtrack ideology scores downloaded from Govtrack.us
# The 2020 report dates from Jan 3 -2019 to Jan 3 - 2021 whereas the 2022 report is dated Jan 3 - 2021 to Jan 3 - 2022. The Govtrack
# report of the current legislators is yet to be released.

# %%
# read the 2020 reports and merge
df_2020_rep = pd.read_csv("raw_data/govtrack-stats-2020-house-ideology.csv")
df_2020_sen = pd.read_csv("raw_data/govtrack-stats-2020-senate-ideology.csv")

df_2020 = pd.concat([df_2020_rep, df_2020_sen])
df_2020.district = df_2020.district.fillna("Senator")
df_2020["period"] = 2020
df_2020.district = df_2020.district.apply(lambda dis: dis if type(dis) == str else dis)

# read the 2022 reports
df_2022_rep = pd.read_csv("raw_data/govtrack-stats-2022-house-ideology.csv")
df_2022_sen = pd.read_csv("raw_data/govtrack-stats-2022-senate-ideology.csv")

df_2022 = pd.concat([df_2022_rep, df_2022_sen])
df_2022["period"] = 2022
df_2022.district = df_2022.district.fillna("Senator")
df_2022.district = df_2022.district.apply(lambda dis: dis if type(dis) == str else dis)

# %% [markdown]
# ### Religious denominations in Congress

# %%
# read religion composition tables

dfs_religion_2020 = tabula.read_pdf(
    "raw_data/Faith-on-the-Hill-116-detailed-tables.pdf", pages="all"
)
dfs_religion_2022 = tabula.read_pdf(
    "raw_data/01.04.21_faith_on_the_hill_detailed.table_.update.pdf", pages="all"
)

# %%
def concat_pdf(dfs_, year):
    "Concatenate religious denominations"
    dfs = []
    for i, df in enumerate(dfs_):
        if i == 0 and year == 2020:
            pass
        else:
            df = pd.concat([df, df.columns.to_frame().T], ignore_index=True)

            if year == 2022:
                df.columns = [
                    "State",
                    "District",
                    "Name",
                    "Party",
                    "Freshman",
                    "Denominational family",
                ]
            else:
                df.columns = dfs_religion_2020[0].columns

        df.District = df.District.apply(
            lambda x: "Senator"
            if x == "Sen" or x == "Senator"
            else "0"
            if x == "At-Large" or x == "At-large"
            else x
        )

        dfs.append(df)

    return pd.concat(dfs)

# %%
df_religion_2020 = concat_pdf(dfs_religion_2020, 2020)
df_religion_2022 = concat_pdf(dfs_religion_2022, 2022)

# concatenate last and full name
df_religion_2020["Full_Name"] = df_religion_2020.apply(
    lambda row: row["First/middle"] + " " + row["Last"], axis=1
)

# %% [markdown]
# ## Veterans in Congress - Data from (militarytimes.com)

# %%
def get_veterans(url):
    # using selenium to acquire veterans in the congress. Data source infogram

    # Create a new Chrome session
    driver = webdriver.Chrome()
    wait = WebDriverWait(driver, 20)

    # Load the web page
    driver.get(url)  # Wait for the page to fully load
    driver.maximize_window()

    wait.until(
        EC.visibility_of_element_located((By.CSS_SELECTOR, ".igc-table-container"))
    )
    # short pause added in order to make sure all the elements are loaded after we know the first element was loaded
    time.sleep(0.5)

    soup = BeautifulSoup(driver.page_source, "lxml")

    div = soup.select_one("div.igc-table-container")

    df = pd.read_html(str(div))[0]

    df["State"] = df.District.apply(
        lambda dis: dis.split(" ")[0] if dis != "Georgia" else "GA"
    )
    df["District"] = df.District.apply(
        lambda dis: "0"
        if len(dis.split(" ")) == 1 or dis.split(" ")[1] == "(House)"
        else str(dis.split(" ")[1])
    )
    df["District"] = df.District.apply(
        lambda dis: "Senator" if dis == "Sen" or dis == "Senate" else dis
    )
    df["Party"] = df.Party.apply(
        lambda party: "R"
        if party == "GOP" or party == "Republican"
        else "D"
        if party == "Dem"
        else party
    )

    return df

# %%
df_mil_2020 = get_veterans(
    "https://e.infogram.com/b28274cb-26b9-441f-9994-a8eb8558839b?src=embed"
)
df_mil_2020.to_csv("raw_data/veterans_in_congress_116.csv", index=False)

df_mil_2022 = get_veterans(
    "https://infogram.com/veterans-in-117th-congress-1hxj48ppv9zz52v"
)
df_mil_2022.to_csv("raw_data/veterans_in_congress_117.csv", index=False)

# %%
# Merge the Congressmen religion and "is veteran" dataframes

df_mil_2020
# Out:
#    District Party              Name In office now?  Gender            Service  \
# 0         9     R      Doug Collins            Yes    Male         AF Reserve
# 1   Senator     R         Mike Enzi            Yes    Male          Air Force
# 2   Senator     R    Lindsey Graham            Yes    Male          Air Force
# 3         6     D  Chrissy Houlahan             No  Female          Air Force
# 4         5     R  Denver Riggleman             No    Male          Air Force
# ..      ...   ...               ...            ...     ...                ...
# 91        1     R       Andy Harris            Yes    Male       Navy Reserve
# 92       20     D     Jimmy Panetta            Yes    Male       Navy Reserve
# 93        3     R         Jim Banks            Yes    Male       Navy Reserve
# 94        4     R    Steven Palazzo            Yes    Male  Marine Corps/Army
# 95  Senator     R    Martha McSally             No  Female          Air Force
#
#             Era       Combat tours State
# 0   2000s-2010s                OIF    GA
# 1   1960s-1970s               none    WY
# 2   1980s-2010s                OIF    SC
# 3         1980s               none    PA
# 4         1990s               none    VA
# ..          ...                ...   ...
# 91  1980s-2010s       Desert Storm    MD
# 92        2000s                OEF    CA
# 93        2010s                OEF    IN
# 94  1980s-2010s  Desert Storm, OIF    MS
# 95  1990s-2010s           OIF, OEF    AZ
#
# [96 rows x 9 columns]

# %%
# match the names and merge the dataframes using Levenshtein logic

import fuzzy_pandas as fpd

# %%
# rename religion dataframe

df_religion_2020.rename(
    columns={"Full_Name": "Name_Rel", "Last": "Last_Name"}, inplace=True
)
df_mil_2020.rename(columns={"Name": "Name_Mil"}, inplace=True)

matches = fpd.fuzzy_merge(
    df_religion_2020,
    df_mil_2020,
    left_on=["Name_Rel", "State", "District", "Party"],
    right_on=["Name_Mil", "State", "District", "Party"],
    method="levenshtein",
    threshold=0.55,
    ignore_case=True,
    ignore_nonalpha=True,
    ignore_nonlatin=True,
    ignore_order_words=True,
)
matches["Military"] = "Yes"

# left join df_religion with matches

df_religion_2020 = df_religion_2020.merge(
    matches[["Name_Rel", "Name_Mil", "Last_Name", "Military"]], how="left"
)
df_religion_2020.Military = df_religion_2020.Military.fillna("No")
df_religion_2020.Last_Name = df_religion_2020.Last_Name.apply(
    lambda name: name.split(" ")[0]
)

# %% [markdown]
# ## Other Congress biographies and social links - source https://github.com/unitedstates/congress-legislators

# %%
congress_historical = pd.read_csv("raw_data/legislators-historical.csv")
congress_current = pd.read_csv("raw_data/legislators-current.csv")
congress_data = pd.concat([congress_historical, congress_current])
congress_data.reset_index(inplace=True, drop=True)

congress_2020_senate = pd.read_csv(
    "raw_data/116th Congress Members Guide with Elections and Demographic Data by District - Senate.csv"
)
congress_2020_house = pd.read_csv(
    "raw_data/116th Congress Members Guide with Elections and Demographic Data by District - House.csv"
)

# %%
congress_data.head(4)
# Out:
#   last_name  first_name middle_name suffix nickname full_name    birthday  \
# 0   Bassett     Richard         NaN    NaN      NaN       NaN  1745-04-02
# 1     Bland  Theodorick         NaN    NaN      NaN       NaN  1742-03-21
# 2     Burke     Aedanus         NaN    NaN      NaN       NaN  1743-06-16
# 3   Carroll      Daniel         NaN    NaN      NaN       NaN  1730-07-22
#
#   gender type state  ...  opensecrets_id  lis_id fec_ids cspan_id govtrack_id  \
# 0      M  sen    DE  ...             NaN     NaN     NaN      NaN      401222
# 1      M  rep    VA  ...             NaN     NaN     NaN      NaN      401521
# 2      M  rep    SC  ...             NaN     NaN     NaN      NaN      402032
# 3      M  rep    MD  ...             NaN     NaN     NaN      NaN      402334
#
#   votesmart_id ballotpedia_id washington_post_id icpsr_id  \
# 0          NaN            NaN                NaN    507.0
# 1          NaN            NaN                NaN    786.0
# 2          NaN            NaN                NaN   1260.0
# 3          NaN            NaN                NaN   1538.0
#
#                             wikipedia_id
# 0  Richard Bassett (Delaware politician)
# 1         Theodorick Bland (congressman)
# 2                          Aedanus Burke
# 3                         Daniel Carroll
#
# [4 rows x 36 columns]

# %%
congress_2020_house["Distr"] = congress_2020_house.Code.apply(
    lambda code: 0 if code.split("-")[1] == "AL" else code.split("-")[1]
)
congress_2020_house["State"] = congress_2020_house.Code.apply(
    lambda code: code.split("-")[0]
)

# %%
congress_2020_senate.head()
# Out:
#      State  Year Class       Party First_Name  Last_Name     First Elected  \
# 0  Alabama  2017    II  Democratic       Doug      Jones      2017 Special
# 1  Alabama  2016   III  Republican    Richard     Shelby              1986
# 2   Alaska  2014    II  Republican        Dan   Sullivan              2014
# 3   Alaska  2016   III  Republican       Lisa  Murkowski  2002 Appointment
# 4  Arizona  2018     I  Democratic    Kyrsten     Sinema              2018
#
#    Birth Year Gender        Race_Ethnicity                    Religion  \
# 0        1954    Man  White - Non-Hispanic       Christian - Methodist
# 1        1934    Man  White - Non-Hispanic    Christian - Presbyterian
# 2        1964    Man  White - Non-Hispanic  Christian - Roman Catholic
# 3        1957  Woman  White - Non-Hispanic  Christian - Roman Catholic
# 4        1976  Woman  White - Non-Hispanic                Unaffiliated
#
#       LGBTQ Pre_2018_Incumbent
# 0        No    Lost in primary
# 1        No             Not up
# 2        No             Not up
# 3        No             Not up
# 4  Bisexual     Open - Retired

# %%
# A python dictionary to abbr US states

us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
congress_2020_senate.State = congress_2020_senate.State.apply(
    lambda x: us_state_to_abbrev[x]
)

# %%
# concatenate the senate and the house dataframes
df_bios_2020 = pd.concat([congress_2020_senate, congress_2020_house])

df_bios_2020.drop(["Year", "Code", "District"], inplace=True, axis=1)
df_bios_2020.rename(
    columns={"Distr": "District", "Class": "Senate Class"}, inplace=True
)

df_bios_2020.District.fillna("Senator", inplace=True)
df_bios_2020["Type"] = df_bios_2020.District.apply(
    lambda district: "sen" if district == "Senator" else "rep"
)

df_bios_2020.reset_index(inplace=True, drop=True)
df_bios_2020.Gender = df_bios_2020.Gender.apply(
    lambda gender: "M" if gender == "Man" else "F" if gender == "Woman" else gender
)

# %%
congress_data.birthday = pd.to_datetime(congress_data.birthday)
congress_data["Birth Year"] = congress_data.birthday.dt.year

# %%
congress_data[congress_data.last_name.str.contains("Manchin")]
# Out:
#       last_name first_name middle_name suffix nickname         full_name  \
# 12162   Manchin        Joe         NaN    III      NaN  Joe Manchin, III
#
#         birthday gender type state  ...  lis_id    fec_ids cspan_id  \
# 12162 1947-08-24      M  sen    WV  ...    S338  S0WV00090  62864.0
#
#       govtrack_id votesmart_id   ballotpedia_id washington_post_id icpsr_id  \
# 12162      412391       7547.0  Joe Manchin III                NaN  40915.0
#
#       wikipedia_id  Birth Year
# 12162  Joe Manchin      1947.0
#
# [1 rows x 37 columns]

# %%
# Join the historical and bios data of the congress members

matches = df_bios_2020.merge(
    congress_data,
    right_on=["last_name", "state", "type", "gender", "Birth Year"],
    left_on=["Last_Name", "State", "Type", "Gender", "Birth Year"],
    how="left",
)

new_df = matches[~matches.govtrack_id.isna()]

# %%
# merge the new dataframe with the govtract scores using govtrack ids

df_ideology = new_df.merge(
    df_2020[["ideology", "id", "bioguide_id"]],
    left_on=["govtrack_id", "bioguide_id"],
    right_on=["id", "bioguide_id"],
    how="left",
)

# %%
def age(born):
    try:
        today = date.today()
        return (
            today.year - born.year - ((today.month, today.day) < (born.month, born.day))
        )
    except (ValueError, TypeError):
        return born  # leave unchanged


df_ideology["age"] = df_ideology.birthday.apply(age)

# %%
df_ideology[~df_ideology.twitter.isna()]
# Out:
#     State Senate Class       Party First_Name  Last_Name     First Elected  \
# 2      AK           II  Republican        Dan   Sullivan              2014
# 3      AK          III  Republican       Lisa  Murkowski  2002 Appointment
# 4      AZ            I  Democratic    Kyrsten     Sinema              2018
# 6      AR           II  Republican        Tom     Cotton              2014
# 7      AR          III  Republican       John    Boozman              2010
# ..    ...          ...         ...        ...        ...               ...
# 499    WI          NaN  Democratic       Mark      Pocan              2012
# 501    WI          NaN  Democratic       Gwen      Moore              2004
# 503    WI          NaN  Republican      Glenn   Grothman              2014
# 504    WI          NaN  Republican        Tom    Tiffany      2020 Special
# 505    WI          NaN  Republican       Mike  Gallagher              2016
#
#      Birth Year Gender            Race_Ethnicity  \
# 2        1964.0      M      White - Non-Hispanic
# 3        1957.0      F      White - Non-Hispanic
# 4        1976.0      F      White - Non-Hispanic
# 6        1977.0      M      White - Non-Hispanic
# 7        1950.0      M      White - Non-Hispanic
# ..          ...    ...                       ...
# 499      1964.0      M      White - Non-Hispanic
# 501      1951.0      F  Black - African-American
# 503      1955.0      M      White - Non-Hispanic
# 504      1957.0      M      White - Non-Hispanic
# 505      1984.0      M      White - Non-Hispanic
#
#                          Religion  ...   cspan_id govtrack_id votesmart_id  \
# 2      Christian - Roman Catholic  ...  1023262.0    412665.0     114964.0
# 3      Christian - Roman Catholic  ...  1004138.0    300075.0      15841.0
# 4                    Unaffiliated  ...    68489.0    412509.0      28338.0
# 6           Christian - Methodist  ...    63928.0    412508.0     135651.0
# 7    Christian - Southern Baptist  ...    92069.0    400040.0      27958.0
# ..                            ...  ...        ...         ...          ...
# 499               Unknown/Refused  ...    79688.0    412585.0      26238.0
# 501           Christian - Baptist  ...    42548.0    400661.0       3457.0
# 503          Christian - Lutheran  ...    77282.0    412661.0       3493.0
# 504                     Christian  ...        NaN    456791.0          NaN
# 505    Christian - Roman Catholic  ...   104067.0    412731.0     171843.0
#
#                     ballotpedia_id washington_post_id icpsr_id  \
# 2               Daniel S. Sullivan                NaN  41500.0
# 3                   Lisa Murkowski                NaN  40300.0
# 4                   Kyrsten Sinema                NaN  21300.0
# 6                       Tom Cotton                NaN  21301.0
# 7                     John Boozman                NaN  20101.0
# ..                             ...                ...      ...
# 499                     Mark Pocan                NaN  21370.0
# 501                     Gwen Moore                NaN  20537.0
# 503                 Glenn Grothman                NaN  21559.0
# 504                    Tom Tiffany                NaN      NaN
# 505  Michael Gallagher (Wisconsin)                NaN  21720.0
#
#                              wikipedia_id  ideology        id age
# 2             Dan Sullivan (U.S. senator)  0.714706  412665.0  58
# 3                          Lisa Murkowski  0.568338  300075.0  66
# 4                          Kyrsten Sinema  0.675805  412509.0  46
# 6                              Tom Cotton  0.933535  412508.0  46
# 7                            John Boozman  0.839497  400040.0  72
# ..                                    ...       ...       ...  ..
# 499                            Mark Pocan  0.174459  412585.0  58
# 501                            Gwen Moore  0.126118  400661.0  72
# 503                        Glenn Grothman  0.816250  412661.0  67
# 504                           Tom Tiffany  0.578802  456791.0  65
# 505  Mike Gallagher (American politician)  0.761699  412731.0  39
#
# [359 rows x 53 columns]

# %%
# save the ideology dataframe

df_ideology.to_csv("raw_data/congress_2020_bios.csv", index=False)

# %% [markdown]
# ### Twitter data and merge with the Biography data

# %%
# read Twitter data

twitter_data = pd.read_csv("raw_data/vader_sentiment_tweets.csv")

# %%
twitter_data.head(5)
# Out:
#               tweet_id       username party  \
# 0  1453097115664662536  RepMikeGarcia     R
# 1  1511713375218245640   RepGallagher     R
# 2  1381021863313350658      RepDLesko     R
# 3  1362468292569534465  RepDebDingell     D
# 4  1551368623142363138    RepCarbajal     D
#
#                                                tweet  \
# 0  I joined fellow China Task Force lawmakers in ...
# 1  Rep. Gallagher: "If we do not invest in hard p...
# 2  CBP is currently encountering over 5,000 peopl...
# 3  It’s past time our country ban discrimination ...
# 4  Proud to present the Woman of the Year Award t...
#
#                                           clean_text  favorite_count  \
# 0   joined fellow china task force lawmakers in s...              43
# 1  rep gallagher if we do not invest in hard powe...              25
# 2  cbp is currently encountering over 000 people ...             283
# 3  it is past time our country ban discrimination...              92
# 4  proud to present the woman of the year award t...              17
#
#    retweet_count                 created_at              source  \
# 0             29  2021-10-26 20:32:04+00:00     Twitter Web App
# 1             11  2022-04-06 14:32:09+00:00     Twitter Web App
# 2             82  2021-04-10 23:10:45+00:00  Twitter for iPhone
# 3             21  2021-02-18 18:25:29+00:00     Twitter Web App
# 4              1  2022-07-25 00:47:57+00:00  Twitter for iPhone
#
#      social_policy  ...  rank score govtrack_cluster progressive_cluster  \
# 0              NaN  ...  #218  0.44                2                   3
# 1              NaN  ...   #52  0.76                4                   4
# 2  Social Policies  ...    #7  0.91                4                   4
# 3  Social Policies  ...  #351  0.25                1                   0
# 4  Social Policies  ...  #283  0.32                1                   0
#
#   govtrack_class  positive_sentiment neutral_sentiment negative_sentiment  \
# 0       Centrist            0.000001          0.807001           0.193001
# 1      Far Right            0.113001          0.786001           0.101001
# 2      Far Right            0.029001          0.860001           0.110001
# 3  Left Centrist            0.086001          0.799001           0.115001
# 4  Left Centrist            0.329001          0.671001           0.000001
#
#    compound_sentiment  sentiment_text
# 0           -0.771699        negative
# 1           -0.128999        negative
# 2           -0.678299        negative
# 3           -0.226299        negative
# 4            0.940301        positive
#
# [5 rows x 27 columns]

# %%
# merge the the biographies with the twitter dataset on username

df = twitter_data.merge(df_ideology, left_on="username", right_on="twitter", how="left")

df.Party = df.Party.apply(
    lambda party: "R"
    if party == "Republican"
    else "D"
    if party == "Democratic"
    else "I"
    if party == "Independent"
    else party
)

# %%
df = df[~df.govtrack_id.isna()]

# %%
# include the military and religion

# df = df.merge(df_religion_2020[["Last_Name", "District", "State", "Party", "Military"]], on=["State", "Last_Name", "District", "Party"], how="left")
# df.Military = df["Military"].fillna("No")

# %% [markdown]
# ## **Multiple Regression Test**
#
# The 2020 Congress report data used in this section.
# <br />
# The output of the model is the sentiment of the tweet whereas the independent variables
# are the ideology score, age, gender identity (LGBTQ), religion and military history of the legislator.

# %%
import statsmodels.formula.api as smf
import numpy as np

# %%
def model(data):
    "model"
    mod = smf.ols(
        formula="compound_sentiment ~ ideology + Party + LGBTQ + Religion + Race_Ethnicity + age",
        data=data,
    )

    return mod.fit()

# %%
df = pd.read_csv("vader_sentiment_tweets.csv")

# %%
christian_categories = {
    "Christian": "Christian",
    "Christian - Roman Catholic": "Christian",
    "Christian - Baptist": "Christian",
    "Christian - Mormon": "Christian",
    "Hindu": "Hindu",
    "Jewish": "Jewish",
    "Christian - Catholic":"Christian",
    "Christian - Evangelical Protestant": "Christian",
    "Christian - Church of God": "Christian",
    "Unknown/Refused": "Unknown",
    "Unaffiliated": "Unaffiliated",
    "Christian - Presbyterian": "Christian",
    "Christian - Methodist": "Christian",
    "Christian - Lutheran": "Christian",
    "Christian - Episcopalian": "Christian",
    "Christian - Southern Baptist": "Christian",
    "Christian - Protestant": "Christian",
    "Christian - Restorationist": "Christian",
    "Christian - Disciples of Christ": "Christian",
    "Christian - Nondenominational": "Christian",
    "Unitarian Universalist": "Christian",
    "Christian - Eastern Orthodox": "Orthodox",
    "Christian - Evangelical Free Church": "Christian",
    "Christian - Pentecostal": "Christian",
    "Christian - Seventh-Day Adventist": "Christian",
    "Christian - Nondenominational Protestant": "Christian",
    "Buddhist - Soka Gakkai": "Buddhist",
    "Muslim": "Muslim",
    "Christian - African Methodist Episcopal": "Christian",
    "Christian - Chaldean Catholic": "Christian",
    "Christian - Congregationalist": "Christian",
    "Christian - United Brethren": "Christian",
    "Christian - Reformed (Calvinist)": "Christian",
}

# %%
ethnicity = {
    "Hispanic - Mexican": "Hispanic",
    "White - Non-Hispanic": "White",
    "Asian - Thai": "Asian",
    "Asian - Indian": "Asian",
    "Black - African-American": "Black",
    "Black - African-American/Asian - Filipino": "Black",
    "Hispanic": "Hispanic",
    "Hispanic - Puerto Rican": "Hispanic",
    "White - Portuguese-American": "White",
    "Native American - Chickasaw": "Native American",
    "Black - Jamaican": "Black",
    "Hispanic - Mexican / Jewish": "Hispanic",
    "Hispanic - Cuban": "Hispanic",
    "Asian - Korean": "Asian",
    "Hispanic - Dominican": "Hispanic",
    "Black - Eritrean": "Black",
    "Black - African-American/Trinidadian": "Black",
    "Hispanic - Mexican/Colombian": "Hispanic",
    "Asian - Chinese": "Asian",
    "Asian - Japanese": "Asian",
    "Hispanic - Guatemalan": "Hispanic",
    "Asian - Taiwanese": "Asian",
    "Native American - Ho-Chunk": "Native American",
    "White - Middle Eastern - Lebanese": "White",
    "White - Middle Eastern - Palestinian": "White",
}

# %%
#  collapse religion and ethnicity

df["Religion"] = df.Religion.apply(lambda x: christian_categories[x])
df["Race_Ethnicity"] = df.Race_Ethnicity.apply(lambda x: ethnicity[x])

# %%
res = model(df)

# %%
df.Party.unique()
# Out:
# array(['Democratic', 'Republican', 'Independent - Dem Caucus'],
#       dtype=object)

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     88.76
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):               0.00
# Time:                        21:56:22   Log-Likelihood:            -1.4273e+05
# No. Observations:              151338   AIC:                         2.855e+05
# Df Residuals:                  151319   BIC:                         2.857e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -2.578e+09   2.39e+09     -1.079      0.281   -7.26e+09    2.11e+09
# Party[T.Independent - Dem Caucus]    -0.0144      0.020     -0.712      0.476      -0.054       0.025
# Party[T.Republican]                  -0.2305      0.008    -27.922      0.000      -0.247      -0.214
# LGBTQ[T.Gay]                       2.578e+09   2.39e+09      1.079      0.281   -2.11e+09    7.26e+09
# LGBTQ[T.Lesbian]                   2.578e+09   2.39e+09      1.079      0.281   -2.11e+09    7.26e+09
# LGBTQ[T.No]                        2.578e+09   2.39e+09      1.079      0.281   -2.11e+09    7.26e+09
# Religion[T.Christian]                -0.0237      0.034     -0.702      0.483      -0.090       0.043
# Religion[T.Hindu]                    -0.1628      0.039     -4.154      0.000      -0.240      -0.086
# Religion[T.Jewish]                   -0.0805      0.034     -2.344      0.019      -0.148      -0.013
# Religion[T.Muslim]                   -0.1422      0.043     -3.342      0.001      -0.226      -0.059
# Religion[T.Orthodox]                  0.0951      0.039      2.446      0.014       0.019       0.171
# Religion[T.Unaffiliated]           2.578e+09   2.39e+09      1.079      0.281   -2.11e+09    7.26e+09
# Religion[T.Unknown]                  -0.0499      0.035     -1.429      0.153      -0.118       0.019
# Race_Ethnicity[T.Black]              -0.0950      0.014     -6.682      0.000      -0.123      -0.067
# Race_Ethnicity[T.Hispanic]           -0.0600      0.014     -4.352      0.000      -0.087      -0.033
# Race_Ethnicity[T.Native American]     0.0831      0.039      2.133      0.033       0.007       0.160
# Race_Ethnicity[T.White]              -0.0163      0.013     -1.264      0.206      -0.042       0.009
# ideology                              0.2394      0.015     16.049      0.000       0.210       0.269
# age                                  -0.0016      0.000    -10.557      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                  1526584.328   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12369.181
# Skew:                          -0.090   Prob(JB):                         0.00
# Kurtosis:                       1.611   Cond. No.                     2.11e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.35e-20. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# regression tests per policy

import json
import string

# open json file consisting of policies and its sub-groups
with open("data.json") as json_file:
    categories = json.load(json_file)

# %%
articles = ["and", "LGBTQ", "the", "of", "CHIPS", "Ukraine-Russia"]

# policies
policies = {**categories["Geo Political Policies"], **categories["Social Policies"]}
policies = list(policies.keys())
policies.remove("All")


for policy in sorted(policies, key=lambda x: x.lower()):
    str_list = string.ascii_uppercase

    title = " ".join(
        [
            word.capitalize() if word not in articles else word
            for word in policy.split(" ")
        ]
    )

    try:
        # category df
        cat_df = df[df.policies.str.contains(r"%s" % policy, re.I, regex=True)]

        res = model(cat_df)

        print(title)
        print(res.summary())
        print(" ")
    except ValueError:
        pass
# Out:
# Abortion
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     6.417
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           1.46e-14
# Time:                        21:57:01   Log-Likelihood:                -6030.0
# No. Observations:                6741   AIC:                         1.209e+04
# Df Residuals:                    6724   BIC:                         1.221e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.6048      0.173      3.504      0.000       0.266       0.943
# Party[T.Independent - Dem Caucus]    -0.1994      0.122     -1.641      0.101      -0.438       0.039
# Party[T.Republican]                   0.1517      0.045      3.368      0.001       0.063       0.240
# LGBTQ[T.Lesbian]                      0.1374      0.100      1.376      0.169      -0.058       0.333
# LGBTQ[T.No]                           0.0342      0.066      0.521      0.602      -0.094       0.163
# Religion[T.Christian]                -0.1839      0.146     -1.262      0.207      -0.470       0.102
# Religion[T.Hindu]                    -0.4153      0.175     -2.374      0.018      -0.758      -0.072
# Religion[T.Jewish]                   -0.2157      0.147     -1.463      0.144      -0.505       0.073
# Religion[T.Muslim]                   -0.3937      0.170     -2.319      0.020      -0.726      -0.061
# Religion[T.Orthodox]                  0.1520      0.165      0.919      0.358      -0.172       0.476
# Religion[T.Unknown]                  -0.2122      0.150     -1.410      0.158      -0.507       0.083
# Race_Ethnicity[T.Black]               0.0313      0.049      0.638      0.524      -0.065       0.127
# Race_Ethnicity[T.Hispanic]           -0.0589      0.051     -1.165      0.244      -0.158       0.040
# Race_Ethnicity[T.Native American]     0.1324      0.193      0.684      0.494      -0.247       0.511
# Race_Ethnicity[T.White]              -0.0315      0.045     -0.706      0.480      -0.119       0.056
# ideology                             -0.3775      0.078     -4.826      0.000      -0.531      -0.224
# age                                  -0.0025      0.001     -3.203      0.001      -0.004      -0.001
# ==============================================================================
# Omnibus:                     6078.033   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              559.318
# Skew:                          -0.369   Prob(JB):                    3.51e-122
# Kurtosis:                       1.798   Cond. No.                     3.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Broadband Internet
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     2.793
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           0.000108
# Time:                        21:57:01   Log-Likelihood:                -3911.3
# No. Observations:                6624   AIC:                             7859.
# Df Residuals:                    6606   BIC:                             7981.
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.3192      0.068      4.660      0.000       0.185       0.453
# Party[T.Independent - Dem Caucus]     0.1064      0.051      2.077      0.038       0.006       0.207
# Party[T.Republican]                  -0.0632      0.024     -2.604      0.009      -0.111      -0.016
# LGBTQ[T.Gay]                          0.0152      0.068      0.224      0.823      -0.118       0.148
# LGBTQ[T.Lesbian]                      0.1078      0.051      2.120      0.034       0.008       0.207
# LGBTQ[T.No]                           0.0249      0.042      0.589      0.556      -0.058       0.108
# Religion[T.Christian]                 0.1074      0.088      1.225      0.221      -0.065       0.279
# Religion[T.Hindu]                     0.1050      0.137      0.768      0.443      -0.163       0.373
# Religion[T.Jewish]                    0.1050      0.090      1.166      0.244      -0.071       0.281
# Religion[T.Muslim]                    0.0162      0.158      0.102      0.918      -0.294       0.327
# Religion[T.Orthodox]                  0.1971      0.112      1.763      0.078      -0.022       0.416
# Religion[T.Unaffiliated]              0.1714      0.072      2.389      0.017       0.031       0.312
# Religion[T.Unknown]                   0.1181      0.091      1.293      0.196      -0.061       0.297
# Race_Ethnicity[T.Black]              -0.0095      0.042     -0.228      0.820      -0.091       0.072
# Race_Ethnicity[T.Hispanic]           -0.0034      0.044     -0.077      0.939      -0.089       0.082
# Race_Ethnicity[T.Native American]    -0.0105      0.100     -0.105      0.916      -0.207       0.186
# Race_Ethnicity[T.White]               0.0174      0.039      0.450      0.653      -0.059       0.093
# ideology                              0.1248      0.049      2.530      0.011       0.028       0.222
# age                                  -0.0013      0.001     -2.586      0.010      -0.002      -0.000
# ==============================================================================
# Omnibus:                      772.522   Durbin-Watson:                   2.035
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1071.851
# Skew:                          -0.979   Prob(JB):                    1.78e-233
# Kurtosis:                       3.220   Cond. No.                     4.22e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.5e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Chinese Communist Party
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     5.951
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           6.00e-14
# Time:                        21:57:02   Log-Likelihood:                -14863.
# No. Observations:               17937   AIC:                         2.976e+04
# Df Residuals:                   17919   BIC:                         2.990e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.2180      0.166      1.315      0.189      -0.107       0.543
# Party[T.Independent - Dem Caucus]    -0.0010      0.077     -0.013      0.990      -0.152       0.150
# Party[T.Republican]                  -0.0779      0.022     -3.553      0.000      -0.121      -0.035
# LGBTQ[T.Gay]                         -0.1859      0.140     -1.330      0.184      -0.460       0.088
# LGBTQ[T.Lesbian]                     -0.1967      0.138     -1.425      0.154      -0.467       0.074
# LGBTQ[T.No]                          -0.1276      0.124     -1.026      0.305      -0.371       0.116
# Religion[T.Christian]                 0.1739      0.230      0.755      0.450      -0.277       0.625
# Religion[T.Hindu]                     0.0672      0.239      0.281      0.778      -0.401       0.535
# Religion[T.Jewish]                    0.0612      0.231      0.265      0.791      -0.392       0.515
# Religion[T.Muslim]                    0.0901      0.263      0.342      0.732      -0.426       0.606
# Religion[T.Orthodox]                  0.2215      0.240      0.923      0.356      -0.249       0.692
# Religion[T.Unaffiliated]              0.7281      0.344      2.115      0.034       0.053       1.403
# Religion[T.Unknown]                   0.0383      0.234      0.164      0.870      -0.420       0.497
# Race_Ethnicity[T.Black]              -0.1187      0.065     -1.813      0.070      -0.247       0.010
# Race_Ethnicity[T.Hispanic]           -0.2005      0.054     -3.717      0.000      -0.306      -0.095
# Race_Ethnicity[T.Native American]     0.2613      0.104      2.521      0.012       0.058       0.464
# Race_Ethnicity[T.White]              -0.1096      0.052     -2.109      0.035      -0.211      -0.008
# ideology                              0.0286      0.037      0.784      0.433      -0.043       0.100
# age                                  -0.0002      0.000     -0.524      0.601      -0.001       0.001
# ==============================================================================
# Omnibus:                    15301.812   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1180.909
# Skew:                          -0.193   Prob(JB):                    3.70e-257
# Kurtosis:                       1.804   Cond. No.                     4.78e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.91e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# CHIPS and Science Act
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     5.003
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           9.87e-11
# Time:                        21:57:02   Log-Likelihood:                -982.43
# No. Observations:                1660   AIC:                             2001.
# Df Residuals:                    1642   BIC:                             2098.
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1862      0.284      0.656      0.512      -0.370       0.743
# Party[T.Independent - Dem Caucus]     0.0587      0.182      0.322      0.747      -0.298       0.416
# Party[T.Republican]                  -0.1999      0.060     -3.313      0.001      -0.318      -0.082
# LGBTQ[T.Gay]                         -0.2926      0.216     -1.352      0.176      -0.717       0.132
# LGBTQ[T.Lesbian]                      0.1893      0.207      0.916      0.360      -0.216       0.594
# LGBTQ[T.No]                          -0.0061      0.184     -0.033      0.974      -0.367       0.355
# Religion[T.Christian]                 0.2087      0.442      0.472      0.637      -0.659       1.076
# Religion[T.Hindu]                     0.1262      0.455      0.278      0.781      -0.765       1.018
# Religion[T.Jewish]                    0.1121      0.444      0.253      0.800      -0.758       0.982
# Religion[T.Muslim]                   -0.2480      0.625     -0.397      0.692      -1.474       0.978
# Religion[T.Orthodox]                  0.5084      0.495      1.028      0.304      -0.462       1.478
# Religion[T.Unaffiliated]              0.2956      0.282      1.048      0.295      -0.257       0.849
# Religion[T.Unknown]                   0.2711      0.446      0.608      0.543      -0.603       1.145
# Race_Ethnicity[T.Black]               0.0426      0.088      0.482      0.630      -0.131       0.216
# Race_Ethnicity[T.Hispanic]            0.1647      0.085      1.928      0.054      -0.003       0.332
# Race_Ethnicity[T.Native American]    -0.0482      0.176     -0.273      0.785      -0.394       0.298
# Race_Ethnicity[T.White]               0.0530      0.076      0.696      0.487      -0.096       0.202
# ideology                              0.0014      0.119      0.012      0.990      -0.233       0.236
# age                                   0.0011      0.001      1.031      0.303      -0.001       0.003
# ==============================================================================
# Omnibus:                      238.396   Durbin-Watson:                   2.058
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              347.641
# Skew:                          -1.099   Prob(JB):                     3.24e-76
# Kurtosis:                       3.437   Cond. No.                     2.34e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Climate Change
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     32.02
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):          1.70e-103
# Time:                        21:57:02   Log-Likelihood:                -20476.
# No. Observations:               23181   AIC:                         4.099e+04
# Df Residuals:                   23163   BIC:                         4.113e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1461      0.068      2.139      0.032       0.012       0.280
# Party[T.Independent - Dem Caucus]    -0.1866      0.032     -5.840      0.000      -0.249      -0.124
# Party[T.Republican]                  -0.3163      0.024    -13.326      0.000      -0.363      -0.270
# LGBTQ[T.Gay]                         -0.1256      0.057     -2.189      0.029      -0.238      -0.013
# LGBTQ[T.Lesbian]                      0.1165      0.059      1.992      0.046       0.002       0.231
# LGBTQ[T.No]                          -0.0113      0.048     -0.236      0.813      -0.105       0.083
# Religion[T.Christian]                -0.0421      0.080     -0.529      0.597      -0.198       0.114
# Religion[T.Hindu]                    -0.3751      0.092     -4.060      0.000      -0.556      -0.194
# Religion[T.Jewish]                   -0.0140      0.081     -0.174      0.862      -0.172       0.144
# Religion[T.Muslim]                   -0.1603      0.101     -1.587      0.112      -0.358       0.038
# Religion[T.Orthodox]                  0.2306      0.091      2.529      0.011       0.052       0.409
# Religion[T.Unaffiliated]              0.1665      0.136      1.227      0.220      -0.100       0.433
# Religion[T.Unknown]                  -0.0342      0.081     -0.421      0.674      -0.193       0.125
# Race_Ethnicity[T.Black]              -0.0564      0.037     -1.514      0.130      -0.129       0.017
# Race_Ethnicity[T.Hispanic]           -0.1026      0.036     -2.880      0.004      -0.172      -0.033
# Race_Ethnicity[T.Native American]     0.0714      0.124      0.577      0.564      -0.171       0.314
# Race_Ethnicity[T.White]              -0.1517      0.033     -4.606      0.000      -0.216      -0.087
# ideology                              0.6804      0.040     17.173      0.000       0.603       0.758
# age                                   0.0008      0.000      1.864      0.062   -4.06e-05       0.002
# ==============================================================================
# Omnibus:                    18077.927   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1871.692
# Skew:                          -0.367   Prob(JB):                         0.00
# Kurtosis:                       1.817   Cond. No.                     5.27e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.48e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Fossil Fuels
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     5.965
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           5.68e-14
# Time:                        21:57:02   Log-Likelihood:                -10543.
# No. Observations:               12322   AIC:                         2.112e+04
# Df Residuals:                   12304   BIC:                         2.126e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0648      0.111      0.582      0.560      -0.153       0.283
# Party[T.Independent - Dem Caucus]    -0.0043      0.045     -0.097      0.923      -0.092       0.084
# Party[T.Republican]                  -0.0926      0.029     -3.227      0.001      -0.149      -0.036
# LGBTQ[T.Gay]                          0.1216      0.101      1.209      0.227      -0.076       0.319
# LGBTQ[T.Lesbian]                      0.3026      0.093      3.267      0.001       0.121       0.484
# LGBTQ[T.No]                          -0.0032      0.079     -0.040      0.968      -0.158       0.151
# Religion[T.Christian]                 0.0223      0.132      0.170      0.865      -0.236       0.281
# Religion[T.Hindu]                    -0.0784      0.151     -0.520      0.603      -0.374       0.217
# Religion[T.Jewish]                    0.0176      0.134      0.132      0.895      -0.244       0.280
# Religion[T.Muslim]                   -0.2523      0.150     -1.679      0.093      -0.547       0.042
# Religion[T.Orthodox]                  0.0685      0.145      0.471      0.638      -0.217       0.354
# Religion[T.Unaffiliated]             -0.3563      0.221     -1.612      0.107      -0.789       0.077
# Religion[T.Unknown]                   0.0797      0.134      0.595      0.552      -0.183       0.342
# Race_Ethnicity[T.Black]               0.0136      0.068      0.199      0.842      -0.120       0.148
# Race_Ethnicity[T.Hispanic]            0.0051      0.063      0.081      0.936      -0.118       0.129
# Race_Ethnicity[T.Native American]    -0.3088      0.117     -2.629      0.009      -0.539      -0.079
# Race_Ethnicity[T.White]              -0.0170      0.060     -0.283      0.777      -0.134       0.100
# ideology                              0.1920      0.049      3.957      0.000       0.097       0.287
# age                                  -0.0013      0.001     -2.345      0.019      -0.002      -0.000
# ==============================================================================
# Omnibus:                    26390.466   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              845.854
# Skew:                          -0.077   Prob(JB):                    2.11e-184
# Kurtosis:                       1.726   Cond. No.                     7.99e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 7.84e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Gun Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.031
# Model:                            OLS   Adj. R-squared:                  0.030
# Method:                 Least Squares   F-statistic:                     48.16
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):          2.25e-160
# Time:                        21:57:03   Log-Likelihood:                -23513.
# No. Observations:               25724   AIC:                         4.706e+04
# Df Residuals:                   25706   BIC:                         4.721e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.3431      0.051     -6.780      0.000      -0.442      -0.244
# Party[T.Independent - Dem Caucus]     0.0490      0.055      0.888      0.375      -0.059       0.157
# Party[T.Republican]                   0.0643      0.020      3.143      0.002       0.024       0.104
# LGBTQ[T.Gay]                         -0.0691      0.043     -1.601      0.109      -0.154       0.016
# LGBTQ[T.Lesbian]                      0.1583      0.047      3.383      0.001       0.067       0.250
# LGBTQ[T.No]                          -0.0513      0.035     -1.480      0.139      -0.119       0.017
# Religion[T.Christian]                 0.0086      0.058      0.149      0.882      -0.104       0.121
# Religion[T.Hindu]                    -0.0132      0.072     -0.184      0.854      -0.154       0.127
# Religion[T.Jewish]                    0.0026      0.059      0.045      0.964      -0.113       0.118
# Religion[T.Muslim]                   -0.1416      0.076     -1.857      0.063      -0.291       0.008
# Religion[T.Orthodox]                  0.1416      0.075      1.895      0.058      -0.005       0.288
# Religion[T.Unaffiliated]             -0.3811      0.094     -4.044      0.000      -0.566      -0.196
# Religion[T.Unknown]                  -0.0173      0.061     -0.285      0.775      -0.136       0.101
# Race_Ethnicity[T.Black]               0.0158      0.028      0.562      0.574      -0.039       0.071
# Race_Ethnicity[T.Hispanic]            0.0125      0.028      0.440      0.660      -0.043       0.068
# Race_Ethnicity[T.Native American]     0.2039      0.127      1.611      0.107      -0.044       0.452
# Race_Ethnicity[T.White]               0.0868      0.026      3.292      0.001       0.035       0.139
# ideology                              0.2589      0.038      6.891      0.000       0.185       0.333
# age                                  -0.0018      0.000     -4.867      0.000      -0.002      -0.001
# ==============================================================================
# Omnibus:                     4630.034   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2938.339
# Skew:                           0.708   Prob(JB):                         0.00
# Kurtosis:                       2.143   Cond. No.                     6.44e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.55e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Immigration and Border Control
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.065
# Model:                            OLS   Adj. R-squared:                  0.064
# Method:                 Least Squares   F-statistic:                     138.2
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):               0.00
# Time:                        21:57:03   Log-Likelihood:                -30444.
# No. Observations:               33839   AIC:                         6.092e+04
# Df Residuals:                   33821   BIC:                         6.108e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1892      0.055      3.415      0.001       0.081       0.298
# Party[T.Independent - Dem Caucus]    -0.1505      0.069     -2.187      0.029      -0.285      -0.016
# Party[T.Republican]                  -0.4220      0.017    -24.759      0.000      -0.455      -0.389
# LGBTQ[T.Gay]                         -0.0721      0.048     -1.505      0.132      -0.166       0.022
# LGBTQ[T.Lesbian]                      0.2180      0.089      2.461      0.014       0.044       0.392
# LGBTQ[T.No]                           0.0634      0.039      1.634      0.102      -0.013       0.139
# Religion[T.Christian]                -0.1312      0.071     -1.845      0.065      -0.271       0.008
# Religion[T.Hindu]                    -0.0587      0.099     -0.594      0.553      -0.252       0.135
# Religion[T.Jewish]                   -0.2154      0.073     -2.953      0.003      -0.358      -0.072
# Religion[T.Muslim]                   -0.2501      0.092     -2.720      0.007      -0.430      -0.070
# Religion[T.Orthodox]                 -0.1420      0.083     -1.715      0.086      -0.304       0.020
# Religion[T.Unaffiliated]             -0.0201      0.061     -0.328      0.743      -0.140       0.100
# Religion[T.Unknown]                  -0.1713      0.077     -2.227      0.026      -0.322      -0.021
# Race_Ethnicity[T.Black]              -0.0085      0.034     -0.254      0.799      -0.074       0.057
# Race_Ethnicity[T.Hispanic]           -0.0018      0.031     -0.057      0.955      -0.062       0.059
# Race_Ethnicity[T.Native American]     0.1230      0.093      1.318      0.187      -0.060       0.306
# Race_Ethnicity[T.White]               0.0488      0.030      1.609      0.108      -0.011       0.108
# ideology                              0.1266      0.029      4.304      0.000       0.069       0.184
# age                                  -0.0006      0.000     -1.986      0.047      -0.001   -8.29e-06
# ==============================================================================
# Omnibus:                    37849.510   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2240.261
# Skew:                           0.152   Prob(JB):                         0.00
# Kurtosis:                       1.777   Cond. No.                     1.14e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  1e-22. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# LGBTQ Community
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     3.601
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           7.24e-07
# Time:                        21:57:04   Log-Likelihood:                -6033.2
# No. Observations:                6073   AIC:                         1.210e+04
# Df Residuals:                    6055   BIC:                         1.222e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.0840      0.120      0.697      0.486      -0.152       0.320
# Party[T.Independent - Dem Caucus]    -0.0868      0.183     -0.474      0.635      -0.446       0.272
# Party[T.Republican]                  -0.1017      0.088     -1.153      0.249      -0.275       0.071
# LGBTQ[T.Gay]                         -0.1237      0.089     -1.394      0.163      -0.298       0.050
# LGBTQ[T.Lesbian]                      0.0853      0.094      0.911      0.362      -0.098       0.269
# LGBTQ[T.No]                          -0.0863      0.085     -1.013      0.311      -0.253       0.081
# Religion[T.Christian]                 0.2032      0.142      1.435      0.151      -0.074       0.481
# Religion[T.Hindu]                     0.0451      0.161      0.281      0.779      -0.270       0.360
# Religion[T.Jewish]                    0.1871      0.144      1.301      0.193      -0.095       0.469
# Religion[T.Muslim]                    0.1893      0.159      1.191      0.234      -0.122       0.501
# Religion[T.Orthodox]                  0.3876      0.163      2.376      0.018       0.068       0.707
# Religion[T.Unaffiliated]              0.2088      0.252      0.828      0.408      -0.285       0.703
# Religion[T.Unknown]                   0.1394      0.145      0.962      0.336      -0.145       0.423
# Race_Ethnicity[T.Black]               0.0444      0.047      0.937      0.349      -0.049       0.137
# Race_Ethnicity[T.Hispanic]            0.0106      0.048      0.220      0.826      -0.084       0.105
# Race_Ethnicity[T.Native American]    -0.0916      0.178     -0.516      0.606      -0.440       0.256
# Race_Ethnicity[T.White]              -0.0086      0.043     -0.200      0.841      -0.093       0.076
# ideology                              0.3433      0.093      3.710      0.000       0.162       0.525
# age                                  -0.0014      0.001     -1.590      0.112      -0.003       0.000
# ==============================================================================
# Omnibus:                     9039.753   Durbin-Watson:                   2.004
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              622.915
# Skew:                          -0.474   Prob(JB):                    5.44e-136
# Kurtosis:                       1.750   Cond. No.                     2.54e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.71e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Substance Abuse and Mental Health
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     10.15
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           1.46e-27
# Time:                        21:57:04   Log-Likelihood:                -11417.
# No. Observations:               11474   AIC:                         2.287e+04
# Df Residuals:                   11456   BIC:                         2.300e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -0.0693      0.092     -0.754      0.451      -0.250       0.111
# Party[T.Independent - Dem Caucus]    -0.1707      0.080     -2.123      0.034      -0.328      -0.013
# Party[T.Republican]                  -0.3203      0.030    -10.731      0.000      -0.379      -0.262
# LGBTQ[T.Gay]                         -0.1362      0.072     -1.900      0.057      -0.277       0.004
# LGBTQ[T.Lesbian]                      0.0853      0.066      1.287      0.198      -0.045       0.215
# LGBTQ[T.No]                           0.0325      0.057      0.567      0.571      -0.080       0.145
# Religion[T.Christian]                 0.1099      0.128      0.858      0.391      -0.141       0.361
# Religion[T.Hindu]                     0.1665      0.149      1.115      0.265      -0.126       0.459
# Religion[T.Jewish]                    0.1078      0.129      0.833      0.405      -0.146       0.362
# Religion[T.Muslim]                    0.0911      0.169      0.540      0.589      -0.239       0.422
# Religion[T.Orthodox]                  0.2512      0.137      1.835      0.067      -0.017       0.520
# Religion[T.Unaffiliated]             -0.0509      0.095     -0.536      0.592      -0.237       0.135
# Religion[T.Unknown]                   0.1403      0.131      1.070      0.285      -0.117       0.397
# Race_Ethnicity[T.Black]              -0.0706      0.048     -1.481      0.139      -0.164       0.023
# Race_Ethnicity[T.Hispanic]           -0.1180      0.048     -2.461      0.014      -0.212      -0.024
# Race_Ethnicity[T.Native American]     0.0052      0.104      0.050      0.960      -0.198       0.209
# Race_Ethnicity[T.White]              -0.0831      0.043     -1.916      0.055      -0.168       0.002
# ideology                              0.4707      0.059      7.926      0.000       0.354       0.587
# age                                  -0.0002      0.001     -0.380      0.704      -0.001       0.001
# ==============================================================================
# Omnibus:                    90134.017   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1084.470
# Skew:                          -0.236   Prob(JB):                    3.24e-236
# Kurtosis:                       1.569   Cond. No.                     4.63e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.1e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
#
# Taiwan
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     7.021
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           1.58e-13
# Time:                        21:57:04   Log-Likelihood:                -1923.9
# No. Observations:                2302   AIC:                             3876.
# Df Residuals:                    2288   BIC:                             3956.
# Df Model:                          13
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.2486      0.402      0.619      0.536      -0.539       1.037
# Party[T.Independent - Dem Caucus]    -0.3046      0.244     -1.247      0.213      -0.784       0.175
# Party[T.Republican]                  -0.0436      0.071     -0.611      0.541      -0.184       0.096
# LGBTQ[T.No]                           0.2295      0.404      0.568      0.570      -0.563       1.022
# Religion[T.Hindu]                    -0.3534      0.103     -3.433      0.001      -0.555      -0.152
# Religion[T.Jewish]                   -0.2041      0.085     -2.403      0.016      -0.371      -0.038
# Religion[T.Orthodox]                  0.6983      0.396      1.763      0.078      -0.078       1.475
# Religion[T.Unknown]                   0.0613      0.160      0.383      0.702      -0.252       0.375
# Race_Ethnicity[T.Black]               0.0646      0.127      0.509      0.611      -0.184       0.313
# Race_Ethnicity[T.Hispanic]           -0.1824      0.095     -1.921      0.055      -0.368       0.004
# Race_Ethnicity[T.Native American]     0.0324      0.294      0.110      0.912      -0.545       0.610
# Race_Ethnicity[T.White]              -0.1908      0.087     -2.186      0.029      -0.362      -0.020
# ideology                             -0.3395      0.113     -2.999      0.003      -0.561      -0.117
# age                                   0.0039      0.001      3.561      0.000       0.002       0.006
# ==============================================================================
# Omnibus:                      452.332   Durbin-Watson:                   2.028
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.526
# Skew:                          -0.488   Prob(JB):                     7.67e-39
# Kurtosis:                       2.064   Cond. No.                     2.94e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Ukraine-Russia
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     compound_sentiment   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     7.778
# Date:                Fri, 16 Jun 2023   Prob (F-statistic):           8.05e-20
# Time:                        21:57:04   Log-Likelihood:                -20963.
# No. Observations:               23887   AIC:                         4.196e+04
# Df Residuals:                   23869   BIC:                         4.211e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             0.1370      0.114      1.205      0.228      -0.086       0.360
# Party[T.Independent - Dem Caucus]     0.0188      0.048      0.394      0.694      -0.075       0.112
# Party[T.Republican]                  -0.1136      0.019     -5.906      0.000      -0.151      -0.076
# LGBTQ[T.Gay]                         -0.0028      0.087     -0.032      0.974      -0.174       0.168
# LGBTQ[T.Lesbian]                      0.1176      0.095      1.239      0.215      -0.068       0.304
# LGBTQ[T.No]                           0.0141      0.077      0.184      0.854      -0.136       0.164
# Religion[T.Christian]                 0.0657      0.169      0.388      0.698      -0.266       0.397
# Religion[T.Hindu]                    -0.1878      0.177     -1.062      0.288      -0.534       0.159
# Religion[T.Jewish]                    0.0044      0.170      0.026      0.980      -0.328       0.337
# Religion[T.Muslim]                    0.1486      0.194      0.765      0.444      -0.232       0.529
# Religion[T.Orthodox]                  0.1633      0.179      0.914      0.361      -0.187       0.514
# Religion[T.Unaffiliated]              0.0081      0.152      0.054      0.957      -0.289       0.305
# Religion[T.Unknown]                   0.0177      0.171      0.103      0.918      -0.318       0.354
# Race_Ethnicity[T.Black]              -0.1575      0.048     -3.278      0.001      -0.252      -0.063
# Race_Ethnicity[T.Hispanic]           -0.1873      0.047     -4.017      0.000      -0.279      -0.096
# Race_Ethnicity[T.Native American]    -0.1959      0.100     -1.964      0.050      -0.391      -0.000
# Race_Ethnicity[T.White]              -0.1335      0.044     -3.021      0.003      -0.220      -0.047
# ideology                              0.0612      0.035      1.766      0.077      -0.007       0.129
# age                                  -0.0007      0.000     -1.778      0.075      -0.001    6.78e-05
# ==============================================================================
# Omnibus:                    91301.512   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1684.775
# Skew:                          -0.019   Prob(JB):                         0.00
# Kurtosis:                       1.700   Cond. No.                     1.89e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.75e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
